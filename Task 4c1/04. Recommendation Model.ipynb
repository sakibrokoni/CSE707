# %%
import numpy as np
import pandas as pd
import ast
import re

# %%
movies = pd.read_csv('25k IMDb movie Dataset.csv')

# %%
movies.shape
# Out:
# (24402, 12)

# %%
movies.head(1)
# Out:
#          movie title                  Run Time Rating User Rating  \
# 0  Top Gun: Maverick  $170,000,000 (estimated)    8.6        187K
#
#                Generes                                           Overview  \
# 0  ['Action', 'Drama']  After more than thirty years of service as one...
#
#                                         Plot Kyeword         Director  \
# 0  ['fighter jet', 'sequel', 'u.s. navy', 'fighte...  Joseph Kosinski
#
#                                          Top 5 Casts    Writer   year  \
# 0  ['Jack Epps Jr.', 'Peter Craig', 'Tom Cruise',...  Jim Cash  -2022
#
#                 path
# 0  /title/tt1745960/

# %%
movies.head(1)['Generes'].values
# Out:
# array(["['Action', 'Drama']"], dtype=object)

# %%
movies.head(1)['Plot Kyeword'].values
# Out:
# array(["['fighter jet', 'sequel', 'u.s. navy', 'fighter aircraft', 'pilot', 'naval aviation', 'jet fighter', 'military pilot', 'aviation', 'aircraft']"],
#       dtype=object)

# %%
movies.head(1)['Overview'].values
# Out:
# array(["After more than thirty years of service as one of the Navy's top aviators, Pete Mitchell is where he belongs, pushing the envelope as a courageous test pilot and dodging the advancement in rank that would ground"],
#       dtype=object)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24402 entries, 0 to 24401
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie title   24402 non-null  object
#  1   Run Time      24402 non-null  object
#  2   Rating        24402 non-null  object
#  3   User Rating   24402 non-null  object
#  4   Generes       24402 non-null  object
#  5   Overview      24158 non-null  object
#  6   Plot Kyeword  24402 non-null  object
#  7   Director      24402 non-null  object
#  8   Top 5 Casts   24402 non-null  object
#  9   Writer        24402 non-null  object
#  10  year          23624 non-null  object
#  11  path          24402 non-null  object
# dtypes: object(12)
# memory usage: 2.2+ MB

# %%
movies.isnull().sum()
# Out:
# movie title       0
# Run Time          0
# Rating            0
# User Rating       0
# Generes           0
# Overview        244
# Plot Kyeword      0
# Director          0
# Top 5 Casts       0
# Writer            0
# year            778
# path              0
# dtype: int64

# %%
# drop missing data column
movies.fillna('', inplace=True)

# %%
movies.isnull().sum()
# Out:
# movie title     0
# Run Time        0
# Rating          0
# User Rating     0
# Generes         0
# Overview        0
# Plot Kyeword    0
# Director        0
# Top 5 Casts     0
# Writer          0
# year            0
# path            0
# dtype: int64

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies.iloc[0].Generes
# Out:
# "['Action', 'Drama']"

# %%
movies['Generes'] = movies['Generes'].apply(lambda x: ast.literal_eval(x))
movies.iloc[0].Generes
# Out:
# ['Action', 'Drama']

# %%
movies.iloc[0].Overview
# Out:
# "After more than thirty years of service as one of the Navy's top aviators, Pete Mitchell is where he belongs, pushing the envelope as a courageous test pilot and dodging the advancement in rank that would ground"

# %%
movies['Overview'] = movies['Overview'].str.split()
movies.iloc[0].Overview
# Out:
# ['After',
#  'more',
#  'than',
#  'thirty',
#  'years',
#  'of',
#  'service',
#  'as',
#  'one',
#  'of',
#  'the',
#  "Navy's",
#  'top',
#  'aviators,',
#  'Pete',
#  'Mitchell',
#  'is',
#  'where',
#  'he',
#  'belongs,',
#  'pushing',
#  'the',
#  'envelope',
#  'as',
#  'a',
#  'courageous',
#  'test',
#  'pilot',
#  'and',
#  'dodging',
#  'the',
#  'advancement',
#  'in',
#  'rank',
#  'that',
#  'would',
#  'ground']

# %%
movies.iloc[0]['Plot Kyeword']
# Out:
# "['fighter jet', 'sequel', 'u.s. navy', 'fighter aircraft', 'pilot', 'naval aviation', 'jet fighter', 'military pilot', 'aviation', 'aircraft']"

# %%
movies['Plot Kyeword'] = movies['Plot Kyeword'].apply(lambda x: ast.literal_eval(x))

# %%
movies.iloc[0]['Plot Kyeword']
# Out:
# ['fighter jet',
#  'sequel',
#  'u.s. navy',
#  'fighter aircraft',
#  'pilot',
#  'naval aviation',
#  'jet fighter',
#  'military pilot',
#  'aviation',
#  'aircraft']

# %%
movies.iloc[0]['Top 5 Casts']
# Out:
# "['Jack Epps Jr.', 'Peter Craig', 'Tom Cruise', 'Jennifer Connelly', 'Miles Teller']"

# %%
movies['Top 5 Casts'] = movies['Top 5 Casts'].apply(lambda x: ast.literal_eval(x))
movies.iloc[0]['Top 5 Casts']
# Out:
# ['Jack Epps Jr.',
#  'Peter Craig',
#  'Tom Cruise',
#  'Jennifer Connelly',
#  'Miles Teller']

# %%
movies.iloc[0]['Director']
# Out:
# 'Joseph Kosinski'

# %%
movies['Director'] = movies['Director'].apply(lambda x: [x])
movies.iloc[0]['Director']
# Out:
# ['Joseph Kosinski']

# %%
movies.iloc[0]['Writer']
# Out:
# 'Jim Cash'

# %%
movies['Writer'] = movies['Writer'].apply(lambda x: [x])
movies.iloc[0]['Writer']
# Out:
# ['Jim Cash']

# %%
movies.iloc[0]['year']
# Out:
# '-2022'

# %%
# define a regular expression pattern to extract the year from the "year" column
year_pattern = r'\d{4}'

# define a function to extract the year from a value in the "year" column
def extract_year(year_value):
    year_match = re.search(year_pattern, str(year_value))
    if year_match:
        return [year_match.group()]
    else:
        return []

# apply the "extract_year" function to the "year" column and create a new column "Year_List"
movies['year'] = movies['year'].apply(extract_year)


movies.iloc[0]['year']
# Out:
# ['2022']

# %%
movies.iloc[1000]['year']
# Out:
# ['1983']

# %%
# define a regular expression pattern to extract the numbers from the "User Rating" column
num_pattern = r'\d+\.?\d*'

# define a function to extract the number from a value in the "User Rating" column
def extract_number(rating_value):
    num_match = re.search(num_pattern, str(rating_value))
    if num_match:
        return float(num_match.group().replace(',', '')) * 1000 if 'K' in rating_value else int(float(num_match.group().replace(',', '')) * 1000000) if 'M' in rating_value else int(num_match.group())
    else:
        return None

# apply the "extract_number" function to the "User Rating" column and create a new column "User_Rating_Int"
movies['User Rating'] = movies['User Rating'].apply(extract_number)

movies.iloc[0]['User Rating']
# Out:
# np.float64(187000.0)

# %%
# create a new column "User_Rating_Quantile" containing the quantile values for each row
movies['User Rating'] = pd.qcut(movies['User Rating'], 100, labels=False, duplicates='drop')

# print the minimum and maximum quantile values
print('Minimum quantile value:', movies['User Rating'].min())
print('Maximum quantile value:', movies['User Rating'].max())
# Out:
# Minimum quantile value: 0
# Maximum quantile value: 90

# %%
movies.iloc[0]['User Rating']
# Out:
# np.int64(86)

# %%
movies['User Rating']
# Out:
# 0        86
# 1        78
# 2        89
# 3        73
# 4        69
#          ..
# 24397    81
# 24398     2
# 24399    12
# 24400    67
# 24401    66
# Name: User Rating, Length: 24402, dtype: int64

# %%
movies['User Rating'] = [f"[{int(x)} quantile value]" for x in movies['User Rating']]

# %%
movies.iloc[0]['User Rating']
# Out:
# '[86 quantile value]'

# %%
movies.head()
# Out:
#                movie title                  Run Time Rating  \
# 0        Top Gun: Maverick  $170,000,000 (estimated)    8.6
# 1  Jurassic World Dominion        2 hours 27 minutes      6
# 2                  Top Gun   $15,000,000 (estimated)    6.9
# 3                Lightyear               $71,101,257    5.2
# 4               Spiderhead              not-released    5.4
#
#            User Rating                         Generes  \
# 0  [86 quantile value]                 [Action, Drama]
# 1  [78 quantile value]     [Action, Adventure, Sci-Fi]
# 2  [89 quantile value]                 [Action, Drama]
# 3  [73 quantile value]  [Animation, Action, Adventure]
# 4  [69 quantile value]          [Action, Crime, Drama]
#
#                                             Overview  \
# 0  [After, more, than, thirty, years, of, service...
# 1  [Four, years, after, the, destruction, of, Isl...
# 2  [As, students, at, the, United, States, Navy's...
# 3  [While, spending, years, attempting, to, retur...
# 4  [In, the, near, future,, convicts, are, offere...
#
#                                         Plot Kyeword           Director  \
# 0  [fighter jet, sequel, u.s. navy, fighter aircr...  [Joseph Kosinski]
# 1  [dinosaur, jurassic park, tyrannosaurus rex, v...  [Colin Trevorrow]
# 2  [pilot, male camaraderie, u.s. navy, grumman f...       [Tony Scott]
# 3  [galaxy, spaceship, robot, rocket, space adven...    [Angus MacLane]
# 4  [discover, medical, test, reality, fictional d...  [Joseph Kosinski]
#
#                                          Top 5 Casts              Writer  \
# 0  [Jack Epps Jr., Peter Craig, Tom Cruise, Jenni...          [Jim Cash]
# 1  [Colin Trevorrow, Derek Connolly, Chris Pratt,...  [Emily Carmichael]
# 2  [Jack Epps Jr., Ehud Yonay, Tom Cruise, Tim Ro...          [Jim Cash]
# 3  [Jason Headley, Matthew Aldrich, Chris Evans, ...     [Angus MacLane]
# 4  [Rhett Reese, Paul Wernick, Chris Hemsworth, M...   [George Saunders]
#
#      year                path
# 0  [2022]   /title/tt1745960/
# 1  [2022]   /title/tt8041270/
# 2  [1986]   /title/tt0092099/
# 3  [2022]  /title/tt10298810/
# 4  [2022]   /title/tt9783600/

# %%
# replace 'no-rating' values with NaN
movies['Rating'].replace('no-rating', np.nan, inplace=True)

# convert 'Rating' column to float type
movies['Rating'] = movies['Rating'].astype(float)

# calculate the mean value of 'Rating' column and replace NaN with the mean value
mean_rating = movies['Rating'].mean()
movies['Rating'].fillna(mean_rating, inplace=True)
# Out:
# /tmp/ipykernel_28396/3735879326.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   movies['Rating'].replace('no-rating', np.nan, inplace=True)
# /tmp/ipykernel_28396/3735879326.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   movies['Rating'].fillna(mean_rating, inplace=True)

# %%
movies['Rating']
# Out:
# 0        8.6
# 1        6.0
# 2        6.9
# 3        5.2
# 4        5.4
#         ...
# 24397    7.6
# 24398    5.5
# 24399    5.1
# 24400    6.4
# 24401    7.1
# Name: Rating, Length: 24402, dtype: float64

# %%
bin_edges = np.linspace(0, 10, 31)
bin_labels = [f"{bin_edges[i]:.4f}-{bin_edges[i+1]:.4f}" for i in range(30)]

# Create a new column with the bin labels for each movie rating
movies['Rating_bin'] = pd.cut(movies['Rating'], bins=bin_edges, labels=bin_labels)

# Format the bin labels to display up to 4 decimal places
movies['Rating_bin'] = movies['Rating_bin'].apply(lambda x: x.replace('(', '').replace(']', '').replace(',', '-'))

# %%
# print the first 10 movies with their rating and rating bin
movies[['movie title', 'Rating', 'Rating_bin']].head(10)
# Out:
#                          movie title    Rating     Rating_bin
# 0                  Top Gun: Maverick  8.600000  8.3333-8.6667
# 1            Jurassic World Dominion  6.000000  5.6667-6.0000
# 2                            Top Gun  6.900000  6.6667-7.0000
# 3                          Lightyear  5.200000  5.0000-5.3333
# 4                         Spiderhead  5.400000  5.3333-5.6667
# 5  Everything Everywhere All at Once  8.300000  8.0000-8.3333
# 6                        Interceptor  4.400000  4.3333-4.6667
# 7                        Interceptor  3.600000  3.3333-3.6667
# 8                         Black Adam  5.935015  5.6667-6.0000
# 9                       The Northman  7.200000  7.0000-7.3333

# %%
movies['Rating_bin'].nunique()
# Out:
# 28

# %%
movies = movies.drop(['Run Time', 'Rating'], axis=1)

# %%
movies.head(1)
# Out:
#          movie title          User Rating          Generes  \
# 0  Top Gun: Maverick  [86 quantile value]  [Action, Drama]
#
#                                             Overview  \
# 0  [After, more, than, thirty, years, of, service...
#
#                                         Plot Kyeword           Director  \
# 0  [fighter jet, sequel, u.s. navy, fighter aircr...  [Joseph Kosinski]
#
#                                          Top 5 Casts      Writer    year  \
# 0  [Jack Epps Jr., Peter Craig, Tom Cruise, Jenni...  [Jim Cash]  [2022]
#
#                 path     Rating_bin
# 0  /title/tt1745960/  8.3333-8.6667

# %%
movies.head()
# Out:
#                movie title          User Rating  \
# 0        Top Gun: Maverick  [86 quantile value]
# 1  Jurassic World Dominion  [78 quantile value]
# 2                  Top Gun  [89 quantile value]
# 3                Lightyear  [73 quantile value]
# 4               Spiderhead  [69 quantile value]
#
#                           Generes  \
# 0                 [Action, Drama]
# 1     [Action, Adventure, Sci-Fi]
# 2                 [Action, Drama]
# 3  [Animation, Action, Adventure]
# 4          [Action, Crime, Drama]
#
#                                             Overview  \
# 0  [After, more, than, thirty, years, of, service...
# 1  [Four, years, after, the, destruction, of, Isl...
# 2  [As, students, at, the, United, States, Navy's...
# 3  [While, spending, years, attempting, to, retur...
# 4  [In, the, near, future,, convicts, are, offere...
#
#                                         Plot Kyeword           Director  \
# 0  [fighter jet, sequel, u.s. navy, fighter aircr...  [Joseph Kosinski]
# 1  [dinosaur, jurassic park, tyrannosaurus rex, v...  [Colin Trevorrow]
# 2  [pilot, male camaraderie, u.s. navy, grumman f...       [Tony Scott]
# 3  [galaxy, spaceship, robot, rocket, space adven...    [Angus MacLane]
# 4  [discover, medical, test, reality, fictional d...  [Joseph Kosinski]
#
#                                          Top 5 Casts              Writer  \
# 0  [Jack Epps Jr., Peter Craig, Tom Cruise, Jenni...          [Jim Cash]
# 1  [Colin Trevorrow, Derek Connolly, Chris Pratt,...  [Emily Carmichael]
# 2  [Jack Epps Jr., Ehud Yonay, Tom Cruise, Tim Ro...          [Jim Cash]
# 3  [Jason Headley, Matthew Aldrich, Chris Evans, ...     [Angus MacLane]
# 4  [Rhett Reese, Paul Wernick, Chris Hemsworth, M...   [George Saunders]
#
#      year                path     Rating_bin
# 0  [2022]   /title/tt1745960/  8.3333-8.6667
# 1  [2022]   /title/tt8041270/  5.6667-6.0000
# 2  [1986]   /title/tt0092099/  6.6667-7.0000
# 3  [2022]  /title/tt10298810/  5.0000-5.3333
# 4  [2022]   /title/tt9783600/  5.3333-5.6667

# %%
# define lambda function to convert string to list and extract first element
def convert_to_str(s):
    str = None
    if isinstance(s, list):
        str =  re.findall('\d+', s[0])[0]
    else:
        str = s.strip().split()[0]
    
    str = str[1:] + ' quantile value'
    return [str]

# apply lambda function to each value in 'User Rating' column
movies['User Rating'] = movies['User Rating'].apply(convert_to_str)
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_28396/3863531097.py:5: SyntaxWarning: invalid escape sequence '\d'
#   str =  re.findall('\d+', s[0])[0]

# %%
movies.head()
# Out:
#                movie title          User Rating  \
# 0        Top Gun: Maverick  [86 quantile value]
# 1  Jurassic World Dominion  [78 quantile value]
# 2                  Top Gun  [89 quantile value]
# 3                Lightyear  [73 quantile value]
# 4               Spiderhead  [69 quantile value]
#
#                           Generes  \
# 0                 [Action, Drama]
# 1     [Action, Adventure, Sci-Fi]
# 2                 [Action, Drama]
# 3  [Animation, Action, Adventure]
# 4          [Action, Crime, Drama]
#
#                                             Overview  \
# 0  [After, more, than, thirty, years, of, service...
# 1  [Four, years, after, the, destruction, of, Isl...
# 2  [As, students, at, the, United, States, Navy's...
# 3  [While, spending, years, attempting, to, retur...
# 4  [In, the, near, future,, convicts, are, offere...
#
#                                         Plot Kyeword           Director  \
# 0  [fighter jet, sequel, u.s. navy, fighter aircr...  [Joseph Kosinski]
# 1  [dinosaur, jurassic park, tyrannosaurus rex, v...  [Colin Trevorrow]
# 2  [pilot, male camaraderie, u.s. navy, grumman f...       [Tony Scott]
# 3  [galaxy, spaceship, robot, rocket, space adven...    [Angus MacLane]
# 4  [discover, medical, test, reality, fictional d...  [Joseph Kosinski]
#
#                                          Top 5 Casts              Writer  \
# 0  [Jack Epps Jr., Peter Craig, Tom Cruise, Jenni...          [Jim Cash]
# 1  [Colin Trevorrow, Derek Connolly, Chris Pratt,...  [Emily Carmichael]
# 2  [Jack Epps Jr., Ehud Yonay, Tom Cruise, Tim Ro...          [Jim Cash]
# 3  [Jason Headley, Matthew Aldrich, Chris Evans, ...     [Angus MacLane]
# 4  [Rhett Reese, Paul Wernick, Chris Hemsworth, M...   [George Saunders]
#
#      year                path     Rating_bin
# 0  [2022]   /title/tt1745960/  8.3333-8.6667
# 1  [2022]   /title/tt8041270/  5.6667-6.0000
# 2  [1986]   /title/tt0092099/  6.6667-7.0000
# 3  [2022]  /title/tt10298810/  5.0000-5.3333
# 4  [2022]   /title/tt9783600/  5.3333-5.6667

# %%
movies['Rating_bin'] = movies['Rating_bin'].astype(str).apply(lambda x: x.split("-"))

# %%
# define a function to join the words in each list and remove spaces
def clean(genres_list):
    return [genre.replace(' ', '') for genre in genres_list]

# apply the clean_genres function to the Generes column
movies['Generes'] = movies['Generes'].apply(clean)
movies['Plot Kyeword'] = movies['Plot Kyeword'].apply(clean)
movies['Director'] = movies['Director'].apply(clean)
movies['Top 5 Casts'] = movies['Top 5 Casts'].apply(clean)
movies['Writer'] = movies['Writer'].apply(clean)
movies['User Rating'] = movies['User Rating'].apply(clean)
movies['Rating_bin'] = movies['Rating_bin'].apply(clean)

# %%
movies.head(1)
# Out:
#          movie title        User Rating          Generes  \
# 0  Top Gun: Maverick  [86quantilevalue]  [Action, Drama]
#
#                                             Overview  \
# 0  [After, more, than, thirty, years, of, service...
#
#                                         Plot Kyeword          Director  \
# 0  [fighterjet, sequel, u.s.navy, fighteraircraft...  [JosephKosinski]
#
#                                          Top 5 Casts     Writer    year  \
# 0  [JackEppsJr., PeterCraig, TomCruise, JenniferC...  [JimCash]  [2022]
#
#                 path        Rating_bin
# 0  /title/tt1745960/  [8.3333, 8.6667]

# %%
# Export the processed DataFrame to a CSV file
movies.to_csv('processed_movies.csv', index=False)
print("Processed data saved to 'processed_movies.csv'")
# Out:
# Processed data saved to 'processed_movies.csv'

# %%
# create new column names tags and concatinate these column
movies['tags'] = movies['User Rating'] + movies['Generes'] + movies['Overview'] + movies['Plot Kyeword'] + movies['Director'] + movies['Top 5 Casts'] + movies['Writer'] + movies['year'] + movies['Rating_bin']

# %%
movies['tags'] = movies['tags'].apply(lambda x: ' '.join(x))

# %%
movies['tags'] = movies['tags'].apply(lambda x: x.lower())

# %%
movies.head(1)
# Out:
#          movie title        User Rating          Generes  \
# 0  Top Gun: Maverick  [86quantilevalue]  [Action, Drama]
#
#                                             Overview  \
# 0  [After, more, than, thirty, years, of, service...
#
#                                         Plot Kyeword          Director  \
# 0  [fighterjet, sequel, u.s.navy, fighteraircraft...  [JosephKosinski]
#
#                                          Top 5 Casts     Writer    year  \
# 0  [JackEppsJr., PeterCraig, TomCruise, JenniferC...  [JimCash]  [2022]
#
#                 path        Rating_bin  \
# 0  /title/tt1745960/  [8.3333, 8.6667]
#
#                                                 tags
# 0  86quantilevalue action drama after more than t...

# %%
new_df = movies[['path','movie title','tags']]
new_df.head()
# Out:
#                  path              movie title  \
# 0   /title/tt1745960/        Top Gun: Maverick
# 1   /title/tt8041270/  Jurassic World Dominion
# 2   /title/tt0092099/                  Top Gun
# 3  /title/tt10298810/                Lightyear
# 4   /title/tt9783600/               Spiderhead
#
#                                                 tags
# 0  86quantilevalue action drama after more than t...
# 1  78quantilevalue action adventure sci-fi four y...
# 2  89quantilevalue action drama as students at th...
# 3  73quantilevalue animation action adventure whi...
# 4  69quantilevalue action crime drama in the near...

# %%
new_df['tags'][0]
# Out:
# "86quantilevalue action drama after more than thirty years of service as one of the navy's top aviators, pete mitchell is where he belongs, pushing the envelope as a courageous test pilot and dodging the advancement in rank that would ground fighterjet sequel u.s.navy fighteraircraft pilot navalaviation jetfighter militarypilot aviation aircraft josephkosinski jackeppsjr. petercraig tomcruise jenniferconnelly milesteller jimcash 2022 8.3333 8.6667"

# %%
new_df['tags'][1]
# Out:
# '78quantilevalue action adventure sci-fi four years after the destruction of isla nublar, dinosaurs now live--and hunt--alongside humans all over the world. this fragile balance will reshape the future and determine, once and for all, whether human beings are to remain the apex predators on a planet they now share with ... read all dinosaur jurassicpark tyrannosaurusrex velociraptor sequel alangrantcharacter elliesattlercharacter ianmalcolmcharacter dinosaurfeature animaltrainer colintrevorrow colintrevorrow derekconnolly chrispratt brycedallashoward lauradern emilycarmichael 2022 5.6667 6.0000'

# %%
movies['tags'] = movies['tags'].apply(lambda x: x.lower())

movies.head(1)
# Out:
#          movie title        User Rating          Generes  \
# 0  Top Gun: Maverick  [86quantilevalue]  [Action, Drama]
#
#                                             Overview  \
# 0  [After, more, than, thirty, years, of, service...
#
#                                         Plot Kyeword          Director  \
# 0  [fighterjet, sequel, u.s.navy, fighteraircraft...  [JosephKosinski]
#
#                                          Top 5 Casts     Writer    year  \
# 0  [JackEppsJr., PeterCraig, TomCruise, JenniferC...  [JimCash]  [2022]
#
#                 path        Rating_bin  \
# 0  /title/tt1745960/  [8.3333, 8.6667]
#
#                                                 tags
# 0  86quantilevalue action drama after more than t...

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y = []
    for i in text.split():
        y.append(ps.stem(i))
    
    return ' '.join(y)

# %%
new_df['tags'] = new_df['tags'].apply(stem)
# Out:
# /tmp/ipykernel_28396/3213734980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 5000, stop_words='english')

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
features = cv.get_feature_names_out()

# %%
len(features)
# Out:
# 5000

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(vectors)

# %%
similarity.shape
# Out:
# (24402, 24402)

# %%
def recommend(movie):
    movie_index = new_df[new_df['movie title'] == movie].index[0]
    distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x:x[1])[1:6]

    return movies_list

# %%
movie_names = ['Batman Begins', 'Top Gun: Maverick', 'Iron Man', "The King's Man"]
for name in movie_names:
    recommended_movies = recommend(name)
    print(f'================{name}====================')
    for i in recommended_movies:
        print(new_df.iloc[i[0]]['movie title'])
# Out:
# ================Batman Begins====================
# The Dark Knight
# The Dark Knight Rises
# The Godson
# Man of Steel
# Sunghursh
# ================Top Gun: Maverick====================
# The Pilot
# Always
# Varayan
# Tierra de valientes
# Balada Si Roy
# ================Iron Man====================
# Iron Man 2
# Blue Beetle
# Captain America: Civil War
# The Avengers
# Thunderbolts
# ================The King's Man====================
# Jhansi I.P.S
# Dark Journey
# The Marvels
# Untitled Superman Project
# The Game

# %%
import pickle

# %%
pickle.dump(new_df,open('movies.pkl','wb'))

# %%
new_df.to_dict()
# Out:
# {'path': {0: '/title/tt1745960/',
#   1: '/title/tt8041270/',
#   2: '/title/tt0092099/',
#   3: '/title/tt10298810/',
#   4: '/title/tt9783600/',
#   5: '/title/tt6710474/',
#   6: '/title/tt14174940/',
#   7: '/title/tt14174940/',
#   8: '/title/tt6443346/',
#   9: '/title/tt11138512/',
#   10: '/title/tt10648342/',
#   11: '/title/tt4123432/',
#   12: '/title/tt11291274/',
#   13: '/title/tt0107290/',
#   14: '/title/tt9419884/',
#   15: '/title/tt2382320/',
#   16: '/title/tt1877830/',
#   17: '/title/tt12593682/',
#   18: '/title/tt12593682/',
#   19: '/title/tt0369610/',
#   20: '/title/tt4881806/',
#   21: '/title/tt9179430/',
#   22: '/title/tt5108870/',
#   23: '/title/tt13320622/',
#   24: '/title/tt10872600/',
#   25: '/title/tt15004136/',
#   26: '/title/tt12412888/',
#   27: '/title/tt1464335/',
#   28: '/title/tt11866324/',
#   29: '/title/tt11866324/',
#   30: '/title/tt11866324/',
#   31: '/title/tt4998632/',
#   32: '/title/tt4998632/',
#   33: '/title/tt0119567/',
#   34: '/title/tt0087182/',
#   35: '/title/tt0087182/',
#   36: '/title/tt0163025/',
#   37: '/title/tt0076759/',
#   38: '/title/tt1649418/',
#   39: '/title/tt4154796/',
#   40: '/title/tt13097336/',
#   41: '/title/tt0325980/',
#   42: '/title/tt9032400/',
#   43: '/title/tt6264654/',
#   44: '/title/tt10838180/',
#   45: '/title/tt0117060/',
#   46: '/title/tt11827628/',
#   47: '/title/tt11827628/',
#   48: '/title/tt0120915/',
#   49: '/title/tt2463208/',
#   50: '/title/tt6856242/',
#   51: '/title/tt0468569/',
#   52: '/title/tt1477834/',
#   53: '/title/tt8367814/',
#   54: '/title/tt4912910/',
#   55: '/title/tt9637132/',
#   56: '/title/tt1856101/',
#   57: '/title/tt1375666/',
#   58: '/title/tt5834426/',
#   59: '/title/tt1630029/',
#   60: '/title/tt9851854/',
#   61: '/title/tt0121766/',
#   62: '/title/tt9603212/',
#   63: '/title/tt10323676/',
#   64: '/title/tt10323676/',
#   65: '/title/tt0098206/',
#   66: '/title/tt1229238/',
#   67: '/title/tt2527338/',
#   68: '/title/tt7097896/',
#   69: '/title/tt0113277/',
#   70: '/title/tt7888964/',
#   71: '/title/tt0499549/',
#   72: '/title/tt6334354/',
#   73: '/title/tt4154756/',
#   74: '/title/tt3501632/',
#   75: '/title/tt11394332/',
#   76: '/title/tt2015381/',
#   77: '/title/tt4244994/',
#   78: '/title/tt0120755/',
#   79: '/title/tt11083552/',
#   80: '/title/tt1790809/',
#   81: '/title/tt0121765/',
#   82: '/title/tt3794354/',
#   83: '/title/tt0120737/',
#   84: '/title/tt9663764/',
#   85: '/title/tt0086190/',
#   86: '/title/tt0948470/',
#   87: '/title/tt2379713/',
#   88: '/title/tt10545296/',
#   89: '/title/tt0409459/',
#   90: '/title/tt6723592/',
#   91: '/title/tt9376612/',
#   92: '/title/tt0087332/',
#   93: '/title/tt1392170/',
#   94: '/title/tt1538403/',
#   95: '/title/tt3480822/',
#   96: '/title/tt0096446/',
#   97: '/title/tt0116629/',
#   98: '/title/tt2381249/',
#   99: '/title/tt0381061/',
#   100: '/title/tt0119116/',
#   101: '/title/tt1431045/',
#   102: '/title/tt1211837/',
#   103: '/title/tt7846844/',
#   104: '/title/tt1840309/',
#   105: '/title/tt2140479/',
#   106: '/title/tt0145487/',
#   107: '/title/tt7985704/',
#   108: '/title/tt12361974/',
#   109: '/title/tt0095016/',
#   110: '/title/tt0317919/',
#   111: '/title/tt0083658/',
#   112: '/title/tt1392190/',
#   113: '/title/tt10698680/',
#   114: '/title/tt14686544/',
#   115: '/title/tt14060094/',
#   116: '/title/tt0383574/',
#   117: '/title/tt2250912/',
#   118: '/title/tt6920084/',
#   119: '/title/tt4154664/',
#   120: '/title/tt0090605/',
#   121: '/title/tt8579674/',
#   122: '/title/tt2488496/',
#   123: '/title/tt0133093/',
#   124: '/title/tt0439572/',
#   125: '/title/tt0172495/',
#   126: '/title/tt2802144/',
#   127: '/title/tt0093773/',
#   128: '/title/tt7991608/',
#   129: '/title/tt4633694/',
#   130: '/title/tt0120616/',
#   131: '/title/tt0372784/',
#   132: '/title/tt2527336/',
#   133: '/title/tt8688634/',
#   134: '/title/tt0472043/',
#   135: '/title/tt0790724/',
#   136: '/title/tt0780504/',
#   137: '/title/tt1298650/',
#   138: '/title/tt1483013/',
#   139: '/title/tt8244784/',
#   140: '/title/tt8244784/',
#   141: '/title/tt0416449/',
#   142: '/title/tt1386697/',
#   143: '/title/tt1345836/',
#   144: '/title/tt0120201/',
#   145: '/title/tt7556122/',
#   146: '/title/tt0167260/',
#   147: '/title/tt0449088/',
#   148: '/title/tt1825683/',
#   149: '/title/tt1631867/',
#   150: '/title/tt5013056/',
#   151: '/title/tt10676048/',
#   152: '/title/tt1469304/',
#   153: '/title/tt0114898/',
#   154: '/title/tt2911666/',
#   155: '/title/tt0117998/',
#   156: '/title/tt0265086/',
#   157: '/title/tt5463162/',
#   158: '/title/tt0800369/',
#   159: '/title/tt1074638/',
#   160: '/title/tt0371746/',
#   161: '/title/tt1321511/',
#   162: '/title/tt1321511/',
#   163: '/title/tt11671006/',
#   164: '/title/tt9114286/',
#   165: '/title/tt1833116/',
#   166: '/title/tt3397884/',
#   167: '/title/tt3778644/',
#   168: '/title/tt0112462/',
#   169: '/title/tt7975244/',
#   170: '/title/tt0848228/',
#   171: '/title/tt0088247/',
#   172: '/title/tt10366206/',
#   173: '/title/tt10298840/',
#   174: '/title/tt2713180/',
#   175: '/title/tt1950186/',
#   176: '/title/tt0413300/',
#   177: '/title/tt9777666/',
#   178: '/title/tt1152836/',
#   179: '/title/tt1270797/',
#   180: '/title/tt6277462/',
#   181: '/title/tt0407304/',
#   182: '/title/tt0407304/',
#   183: '/title/tt1502712/',
#   184: '/title/tt0458339/',
#   185: '/title/tt0103064/',
#   186: '/title/tt0942385/',
#   187: '/title/tt0796366/',
#   188: '/title/tt1663202/',
#   189: '/title/tt5034838/',
#   190: '/title/tt6791350/',
#   191: '/title/tt15239678/',
#   192: '/title/tt0369339/',
#   193: '/title/tt8356942/',
#   194: '/title/tt3890160/',
#   195: '/title/tt3829920/',
#   196: '/title/tt0443649/',
#   197: '/title/tt8106534/',
#   198: '/title/tt4428398/',
#   199: '/title/tt1872181/',
#   200: '/title/tt0870154/',
#   201: '/title/tt6654210/',
#   202: '/title/tt0232500/',
#   203: '/title/tt3896198/',
#   204: '/title/tt5433140/',
#   205: '/title/tt0974015/',
#   206: '/title/tt0096895/',
#   207: '/title/tt0096895/',
#   208: '/title/tt8912936/',
#   209: '/title/tt9362722/',
#   210: '/title/tt0111257/',
#   211: '/title/tt0097576/',
#   212: '/title/tt0325710/',
#   213: '/title/tt0325710/',
#   214: '/title/tt0418279/',
#   215: '/title/tt3315342/',
#   216: '/title/tt0120591/',
#   217: '/title/tt6320628/',
#   218: '/title/tt7798634/',
#   219: '/title/tt0109506/',
#   220: '/title/tt0266697/',
#   221: '/title/tt0181689/',
#   222: '/title/tt1677720/',
#   223: '/title/tt2582782/',
#   224: '/title/tt0770828/',
#   225: '/title/tt0167261/',
#   226: '/title/tt10696784/',
#   227: '/title/tt1250777/',
#   228: '/title/tt0448115/',
#   229: '/title/tt2283362/',
#   230: '/title/tt0317705/',
#   231: '/title/tt0118880/',
#   232: '/title/tt7126948/',
#   233: '/title/tt2397535/',
#   234: '/title/tt0087469/',
#   235: '/title/tt2395427/',
#   236: '/title/tt2935622/',
#   237: '/title/tt0964517/',
#   238: '/title/tt4649466/',
#   239: '/title/tt0451279/',
#   240: '/title/tt0448011/',
#   241: '/title/tt0293429/',
#   242: '/title/tt1156398/',
#   243: '/title/tt9243946/',
#   244: '/title/tt2404435/',
#   245: '/title/tt1386588/',
#   246: '/title/tt5090568/',
#   247: '/title/tt2274648/',
#   248: '/title/tt1790864/',
#   249: '/title/tt5109280/',
#   250: '/title/tt0119654/',
#   251: '/title/tt10151854/',
#   252: '/title/tt11656220/',
#   253: '/title/tt0993840/',
#   254: '/title/tt8385148/',
#   255: '/title/tt0446029/',
#   256: '/title/tt3498820/',
#   257: '/title/tt1959563/',
#   258: '/title/tt3829266/',
#   259: '/title/tt0830515/',
#   260: '/title/tt0099371/',
#   261: '/title/tt1013743/',
#   262: '/title/tt0936501/',
#   263: '/title/tt0110475/',
#   264: '/title/tt0106977/',
#   265: '/title/tt1981115/',
#   266: '/title/tt2404233/',
#   267: '/title/tt6718412/',
#   268: '/title/tt1979320/',
#   269: '/title/tt8936646/',
#   270: '/title/tt0117500/',
#   271: '/title/tt0816711/',
#   272: '/title/tt1440129/',
#   273: '/title/tt7838252/',
#   274: '/title/tt7529298/',
#   275: '/title/tt0118688/',
#   276: '/title/tt1243957/',
#   277: '/title/tt0437086/',
#   278: '/title/tt0103776/',
#   279: '/title/tt1637688/',
#   280: '/title/tt0455944/',
#   281: '/title/tt15009428/',
#   282: '/title/tt0434409/',
#   283: '/title/tt7558982/',
#   284: '/title/tt0258463/',
#   285: '/title/tt0102685/',
#   286: '/title/tt3717490/',
#   287: '/title/tt0978764/',
#   288: '/title/tt0120903/',
#   289: '/title/tt6246322/',
#   290: '/title/tt13024674/',
#   291: '/title/tt0078346/',
#   292: '/title/tt0800080/',
#   293: '/title/tt0091203/',
#   294: '/title/tt9900782/',
#   295: '/title/tt0320661/',
#   296: '/title/tt7737786/',
#   297: '/title/tt0918940/',
#   298: '/title/tt4779682/',
#   299: '/title/tt2704998/',
#   300: '/title/tt3385516/',
#   301: '/title/tt1972591/',
#   302: '/title/tt1259528/',
#   303: '/title/tt0119094/',
#   304: '/title/tt1618434/',
#   305: '/title/tt0106660/',
#   306: '/title/tt0116367/',
#   307: '/title/tt1951264/',
#   308: '/title/tt5164214/',
#   309: '/title/tt1245526/',
#   310: '/title/tt0087538/',
#   311: '/title/tt0113189/',
#   312: '/title/tt0892769/',
#   313: '/title/tt0100802/',
#   314: '/title/tt0910936/',
#   315: '/title/tt1291584/',
#   316: '/title/tt7319486/',
#   317: '/title/tt3393786/',
#   318: '/title/tt0373889/',
#   319: '/title/tt0425112/',
#   320: '/title/tt3640424/',
#   321: '/title/tt3532216/',
#   322: '/title/tt0083944/',
#   323: '/title/tt4682266/',
#   324: '/title/tt0116213/',
#   325: '/title/tt1734493/',
#   326: '/title/tt11558688/',
#   327: '/title/tt0139654/',
#   328: '/title/tt2222042/',
#   329: '/title/tt0187393/',
#   330: '/title/tt1192628/',
#   331: '/title/tt2076822/',
#   332: '/title/tt0493464/',
#   333: '/title/tt0120812/',
#   334: '/title/tt13863334/',
#   335: '/title/tt0316654/',
#   336: '/title/tt3371366/',
#   337: '/title/tt0095631/',
#   338: '/title/tt21028848/',
#   339: '/title/tt4530422/',
#   340: '/title/tt0055928/',
#   341: '/title/tt8784956/',
#   342: '/title/tt0082198/',
#   343: '/title/tt1365519/',
#   344: '/title/tt12731980/',
#   345: '/title/tt0417741/',
#   346: '/title/tt0074812/',
#   347: '/title/tt1843866/',
#   348: '/title/tt0099739/',
#   349: '/title/tt0316356/',
#   350: '/title/tt0102803/',
#   351: '/title/tt3799694/',
#   352: '/title/tt0213149/',
#   353: '/title/tt1706620/',
#   354: '/title/tt0441773/',
#   355: '/title/tt1276104/',
#   356: '/title/tt6146586/',
#   357: '/title/tt2975590/',
#   358: '/title/tt3062096/',
#   359: '/title/tt3062096/',
#   360: '/title/tt0133152/',
#   361: '/title/tt0360717/',
#   362: '/title/tt0093507/',
#   363: '/title/tt0076729/',
#   364: '/title/tt0430357/',
#   365: '/title/tt4139588/',
#   366: '/title/tt0120735/',
#   367: '/title/tt0489099/',
#   368: '/title/tt4566758/',
#   369: '/title/tt0120611/',
#   370: '/title/tt1190080/',
#   371: '/title/tt6020800/',
#   372: '/title/tt6020800/',
#   373: '/title/tt0319262/',
#   374: '/title/tt0080120/',
#   375: '/title/tt0080120/',
#   376: '/title/tt4172430/',
#   377: '/title/tt6079772/',
#   378: '/title/tt0100758/',
#   379: '/title/tt0100758/',
#   380: '/title/tt0356910/',
#   381: '/title/tt1228705/',
#   382: '/title/tt0360486/',
#   383: '/title/tt1663662/',
#   384: '/title/tt3606756/',
#   385: '/title/tt0478970/',
#   386: '/title/tt1046173/',
#   387: '/title/tt2245084/',
#   388: '/title/tt0328107/',
#   389: '/title/tt6450804/',
#   390: '/title/tt1877832/',
#   391: '/title/tt2854926/',
#   392: '/title/tt2854926/',
#   393: '/title/tt0955308/',
#   394: '/title/tt1489889/',
#   395: '/title/tt1028528/',
#   396: '/title/tt0822854/',
#   397: '/title/tt1023111/',
#   398: '/title/tt6189022/',
#   399: '/title/tt13406136/',
#   400: '/title/tt0337978/',
#   401: '/title/tt1343727/',
#   402: '/title/tt5033998/',
#   403: '/title/tt2679042/',
#   404: '/title/tt0463985/',
#   405: '/title/tt0465494/',
#   406: '/title/tt0465494/',
#   407: '/title/tt1488606/',
#   408: '/title/tt1232829/',
#   409: '/title/tt0803096/',
#   410: '/title/tt0106856/',
#   411: '/title/tt1136608/',
#   412: '/title/tt0093870/',
#   413: '/title/tt0209163/',
#   414: '/title/tt0086960/',
#   415: '/title/tt5884052/',
#   416: '/title/tt2660888/',
#   417: '/title/tt5748448/',
#   418: '/title/tt0206634/',
#   419: '/title/tt1638355/',
#   420: '/title/tt2179136/',
#   421: '/title/tt15422240/',
#   422: '/title/tt1206885/',
#   423: '/title/tt0120804/',
#   424: '/title/tt6998518/',
#   425: '/title/tt0120347/',
#   426: '/title/tt6924650/',
#   427: '/title/tt2873282/',
#   428: '/title/tt0100485/',
#   429: '/title/tt10600398/',
#   430: '/title/tt5500218/',
#   431: '/title/tt5774060/',
#   432: '/title/tt1013752/',
#   433: '/title/tt0381849/',
#   434: '/title/tt0079501/',
#   435: '/title/tt0093692/',
#   436: '/title/tt0480255/',
#   437: '/title/tt0102059/',
#   438: '/title/tt0399146/',
#   439: '/title/tt8368408/',
#   440: '/title/tt4630562/',
#   441: '/title/tt5439796/',
#   442: '/title/tt1234719/',
#   443: '/title/tt1234719/',
#   444: '/title/tt14849038/',
#   445: '/title/tt14849038/',
#   446: '/title/tt0286716/',
#   447: '/title/tt10954600/',
#   448: '/title/tt0111282/',
#   449: '/title/tt0104691/',
#   450: '/title/tt0099422/',
#   451: '/title/tt0120873/',
#   452: '/title/tt3741700/',
#   453: '/title/tt1390411/',
#   454: '/title/tt3410834/',
#   455: '/title/tt0120647/',
#   456: '/title/tt0808151/',
#   457: '/title/tt0080455/',
#   458: '/title/tt0938283/',
#   459: '/title/tt0114214/',
#   460: '/title/tt0988045/',
#   461: '/title/tt1037705/',
#   462: '/title/tt5052474/',
#   463: '/title/tt3731562/',
#   464: '/title/tt2271563/',
#   465: '/title/tt2271563/',
#   466: '/title/tt1596343/',
#   467: '/title/tt1735898/',
#   468: '/title/tt1408101/',
#   469: '/title/tt4701182/',
#   470: '/title/tt14641788/',
#   471: '/title/tt15838850/',
#   472: '/title/tt9263550/',
#   473: '/title/tt1197624/',
#   474: '/title/tt7737528/',
#   475: '/title/tt0149261/',
#   476: '/title/tt4425200/',
#   477: '/title/tt0096256/',
#   478: '/title/tt0120053/',
#   479: '/title/tt1424381/',
#   480: '/title/tt2980592/',
#   481: '/title/tt1785635/',
#   482: '/title/tt1785635/',
#   483: '/title/tt6263850/',
#   484: '/title/tt2120120/',
#   485: '/title/tt0338526/',
#   486: '/title/tt7149730/',
#   487: '/title/tt0122718/',
#   488: '/title/tt0099423/',
#   489: '/title/tt0272020/',
#   490: '/title/tt0368891/',
#   491: '/title/tt1981128/',
#   492: '/title/tt6806448/',
#   493: '/title/tt1628841/',
#   494: '/title/tt5095030/',
#   495: '/title/tt13287846/',
#   496: '/title/tt13287846/',
#   497: '/title/tt1133985/',
#   498: '/title/tt0090728/',
#   499: '/title/tt5461944/',
#   500: '/title/tt0458525/',
#   501: '/title/tt13919802/',
#   502: '/title/tt13302660/',
#   503: '/title/tt1980209/',
#   504: '/title/tt0480249/',
#   505: '/title/tt6048922/',
#   506: '/title/tt2872732/',
#   507: '/title/tt10327252/',
#   508: '/title/tt1650062/',
#   509: '/title/tt8114980/',
#   510: '/title/tt1325004/',
#   511: '/title/tt1846589/',
#   512: '/title/tt2302755/',
#   513: '/title/tt1502397/',
#   514: '/title/tt0088011/',
#   515: '/title/tt1964418/',
#   516: '/title/tt0093640/',
#   517: '/title/tt0093640/',
#   518: '/title/tt0405325/',
#   519: '/title/tt0405325/',
#   520: '/title/tt0259324/',
#   521: '/title/tt0112442/',
#   522: '/title/tt0453467/',
#   523: '/title/tt1060277/',
#   524: '/title/tt1409024/',
#   525: '/title/tt0433362/',
#   526: '/title/tt15391770/',
#   527: '/title/tt0320691/',
#   528: '/title/tt1160996/',
#   529: '/title/tt1160996/',
#   530: '/title/tt1502404/',
#   531: '/title/tt0097428/',
#   532: '/title/tt3833480/',
#   533: '/title/tt0110632/',
#   534: '/title/tt0164052/',
#   535: '/title/tt0118928/',
#   536: '/title/tt0401729/',
#   537: '/title/tt0234215/',
#   538: '/title/tt0090264/',
#   539: '/title/tt0099810/',
#   540: '/title/tt9247314/',
#   541: '/title/tt9247314/',
#   542: '/title/tt9247314/',
#   543: '/title/tt9247314/',
#   544: '/title/tt0103644/',
#   545: '/title/tt12263384/',
#   546: '/title/tt2209764/',
#   547: '/title/tt0058150/',
#   548: '/title/tt0293662/',
#   549: '/title/tt0089880/',
#   550: '/title/tt4052882/',
#   551: '/title/tt0102798/',
#   552: '/title/tt6306064/',
#   553: '/title/tt0322259/',
#   554: '/title/tt0082340/',
#   555: '/title/tt7456310/',
#   556: '/title/tt10023022/',
#   557: '/title/tt0367882/',
#   558: '/title/tt0062765/',
#   559: '/title/tt2025690/',
#   560: '/title/tt13314558/',
#   561: '/title/tt0100403/',
#   562: '/title/tt4522918/',
#   563: '/title/tt4522918/',
#   564: '/title/tt0227538/',
#   565: '/title/tt0831387/',
#   566: '/title/tt1490017/',
#   567: '/title/tt0378194/',
#   568: '/title/tt0056197/',
#   569: '/title/tt0143145/',
#   570: '/title/tt0245844/',
#   571: '/title/tt2406566/',
#   572: '/title/tt1091191/',
#   573: '/title/tt14412366/',
#   574: '/title/tt0230011/',
#   575: '/title/tt0379786/',
#   576: '/title/tt0363547/',
#   577: '/title/tt0329101/',
#   578: '/title/tt0066999/',
#   579: '/title/tt1340138/',
#   580: '/title/tt0088944/',
#   581: '/title/tt0071571/',
#   582: '/title/tt0071571/',
#   583: '/title/tt0107362/',
#   584: '/title/tt4978420/',
#   585: '/title/tt0144117/',
#   586: '/title/tt1650554/',
#   587: '/title/tt1727776/',
#   588: '/title/tt6499752/',
#   589: '/title/tt0053125/',
#   590: '/title/tt1253863/',
#   591: '/title/tt0086393/',
#   592: '/title/tt0376994/',
#   593: '/title/tt0118615/',
#   594: '/title/tt1571234/',
#   595: '/title/tt8790086/',
#   596: '/title/tt0096487/',
#   597: '/title/tt9274670/',
#   598: '/title/tt9274670/',
#   599: '/title/tt0190374/',
#   600: '/title/tt0190374/',
#   601: '/title/tt0070328/',
#   602: '/title/tt2239822/',
#   603: '/title/tt0099938/',
#   604: '/title/tt10059518/',
#   605: '/title/tt1809398/',
#   606: '/title/tt1454468/',
#   607: '/title/tt0057076/',
#   608: '/title/tt1951266/',
#   609: '/title/tt0253556/',
#   610: '/title/tt0111503/',
#   611: '/title/tt5886046/',
#   612: '/title/tt0093894/',
#   613: '/title/tt0183790/',
#   614: '/title/tt3215824/',
#   615: '/title/tt4479380/',
#   616: '/title/tt2557478/',
#   617: '/title/tt0115624/',
#   618: '/title/tt9844522/',
#   619: '/title/tt5635026/',
#   620: '/title/tt0806203/',
#   621: '/title/tt0112851/',
#   622: '/title/tt0406816/',
#   623: '/title/tt0406816/',
#   624: '/title/tt0118571/',
#   625: '/title/tt0120179/',
#   626: '/title/tt0465580/',
#   627: '/title/tt1606378/',
#   628: '/title/tt0091225/',
#   629: '/title/tt0097742/',
#   630: '/title/tt1921064/',
#   631: '/title/tt0076752/',
#   632: '/title/tt3110958/',
#   633: '/title/tt0330793/',
#   634: '/title/tt0082136/',
#   635: '/title/tt1411250/',
#   636: '/title/tt0449010/',
#   637: '/title/tt6475714/',
#   638: '/title/tt0246460/',
#   639: '/title/tt3949660/',
#   640: '/title/tt0059800/',
#   641: '/title/tt2109248/',
#   642: '/title/tt0375912/',
#   643: '/title/tt2267968/',
#   644: '/title/tt0800320/',
#   645: '/title/tt4029412/',
#   646: '/title/tt8589850/',
#   647: '/title/tt10731768/',
#   648: '/title/tt2283336/',
#   649: '/title/tt0087262/',
#   650: '/title/tt0071807/',
#   651: '/title/tt1655444/',
#   652: '/title/tt0129167/',
#   653: '/title/tt1583421/',
#   654: '/title/tt0120912/',
#   655: '/title/tt0065214/',
#   656: '/title/tt0359013/',
#   657: '/title/tt2126355/',
#   658: '/title/tt0110478/',
#   659: '/title/tt1560220/',
#   660: '/title/tt1220719/',
#   661: '/title/tt0399201/',
#   662: '/title/tt0092675/',
#   663: '/title/tt0064757/',
#   664: '/title/tt2386490/',
#   665: '/title/tt0082398/',
#   666: '/title/tt1210819/',
#   667: '/title/tt1318514/',
#   668: '/title/tt0093409/',
#   669: '/title/tt1267297/',
#   670: '/title/tt1267297/',
#   671: '/title/tt0295178/',
#   672: '/title/tt0296572/',
#   673: '/title/tt0458481/',
#   674: '/title/tt0277434/',
#   675: '/title/tt0346491/',
#   676: '/title/tt0145660/',
#   677: '/title/tt0112715/',
#   678: '/title/tt2719848/',
#   679: '/title/tt2304933/',
#   680: '/title/tt4116284/',
#   681: '/title/tt0479528/',
#   682: '/title/tt3450958/',
#   683: '/title/tt1032755/',
#   684: '/title/tt4196776/',
#   685: '/title/tt2334879/',
#   686: '/title/tt0438488/',
#   687: '/title/tt3045616/',
#   688: '/title/tt1001526/',
#   689: '/title/tt2312718/',
#   690: '/title/tt4500922/',
#   691: '/title/tt3766354/',
#   692: '/title/tt1413492/',
#   693: '/title/tt1535108/',
#   694: '/title/tt14123284/',
#   695: '/title/tt2333784/',
#   696: '/title/tt2103281/',
#   697: '/title/tt1302011/',
#   698: '/title/tt1335975/',
#   699: '/title/tt15326988/',
#   700: '/title/tt12302540/',
#   701: '/title/tt12302540/',
#   702: '/title/tt0285823/',
#   703: '/title/tt0475394/',
#   704: '/title/tt1428538/',
#   705: '/title/tt1951265/',
#   706: '/title/tt0462499/',
#   707: '/title/tt0106697/',
#   708: '/title/tt0080745/',
#   709: '/title/tt0083511/',
#   710: '/title/tt0093428/',
#   711: '/title/tt0311113/',
#   712: '/title/tt0945513/',
#   713: '/title/tt10687220/',
#   714: '/title/tt0089489/',
#   715: '/title/tt0120768/',
#   716: '/title/tt3079380/',
#   717: '/title/tt2094116/',
#   718: '/title/tt1055369/',
#   719: '/title/tt10579952/',
#   720: '/title/tt10579952/',
#   721: '/title/tt0372183/',
#   722: '/title/tt0066995/',
#   723: '/title/tt6679794/',
#   724: '/title/tt0463854/',
#   725: '/title/tt1253864/',
#   726: '/title/tt2328678/',
#   727: '/title/tt0348150/',
#   728: '/title/tt0287978/',
#   729: '/title/tt1399103/',
#   730: '/title/tt2231461/',
#   731: '/title/tt10121392/',
#   732: '/title/tt0349683/',
#   733: '/title/tt0317740/',
#   734: '/title/tt1430132/',
#   735: '/title/tt0119099/',
#   736: '/title/tt9362930/',
#   737: '/title/tt1959490/',
#   738: '/title/tt2381991/',
#   739: '/title/tt2479478/',
#   740: '/title/tt0061578/',
#   741: '/title/tt0070909/',
#   742: '/title/tt0087065/',
#   743: '/title/tt8242084/',
#   744: '/title/tt0120660/',
#   745: '/title/tt0172156/',
#   746: '/title/tt0499097/',
#   747: '/title/tt0086567/',
#   748: '/title/tt14479746/',
#   749: '/title/tt1320253/',
#   750: '/title/tt1528100/',
#   751: '/title/tt4334266/',
#   752: '/title/tt1374989/',
#   753: '/title/tt1646971/',
#   754: '/title/tt0770752/',
#   755: '/title/tt5519340/',
#   756: '/title/tt0086034/',
#   757: '/title/tt0181852/',
#   758: '/title/tt1634106/',
#   759: '/title/tt2024469/',
#   760: '/title/tt0114508/',
#   761: '/title/tt0120746/',
#   762: '/title/tt12037194/',
#   763: '/title/tt3967856/',
#   764: '/title/tt0079574/',
#   765: '/title/tt0057193/',
#   766: '/title/tt0429493/',
#   767: '/title/tt0094625/',
#   768: '/title/tt0343818/',
#   769: '/title/tt1034032/',
#   770: '/title/tt18689424/',
#   771: '/title/tt0187738/',
#   772: '/title/tt0433035/',
#   773: '/title/tt1706593/',
#   774: '/title/tt8629748/',
#   775: '/title/tt0390022/',
#   776: '/title/tt6402468/',
#   777: '/title/tt0242653/',
#   778: '/title/tt1137450/',
#   779: '/title/tt0499448/',
#   780: '/title/tt5884234/',
#   781: '/title/tt0417148/',
#   782: '/title/tt1515091/',
#   783: '/title/tt2377322/',
#   784: '/title/tt2377322/',
#   785: '/title/tt13918550/',
#   786: '/title/tt1536537/',
#   787: '/title/tt6878306/',
#   788: '/title/tt3300542/',
#   789: '/title/tt1731141/',
#   790: '/title/tt1077258/',
#   791: '/title/tt0113820/',
#   792: '/title/tt7903530/',
#   793: '/title/tt0238380/',
#   794: '/title/tt0105690/',
#   795: '/title/tt0419706/',
#   796: '/title/tt0266915/',
#   797: '/title/tt0475944/',
#   798: '/title/tt0134847/',
#   799: '/title/tt0486946/',
#   800: '/title/tt1551614/',
#   801: '/title/tt0120744/',
#   802: '/title/tt18259086/',
#   803: '/title/tt10228134/',
#   804: '/title/tt3531824/',
#   805: '/title/tt4046784/',
#   806: '/title/tt12422308/',
#   807: '/title/tt3312180/',
#   808: '/title/tt6902676/',
#   809: '/title/tt0351977/',
#   810: '/title/tt0452608/',
#   811: '/title/tt2002718/',
#   812: '/title/tt0960144/',
#   813: '/title/tt1855199/',
#   814: '/title/tt7550000/',
#   815: '/title/tt10598156/',
#   816: '/title/tt14961624/',
#   817: '/title/tt1509767/',
#   818: '/title/tt0473075/',
#   819: '/title/tt0085811/',
#   820: '/title/tt0062512/',
#   821: '/title/tt0472033/',
#   822: '/title/tt0472033/',
#   823: '/title/tt14824600/',
#   824: '/title/tt6442686/',
#   825: '/title/tt1535109/',
#   826: '/title/tt0061418/',
#   827: '/title/tt2094766/',
#   828: '/title/tt9115574/',
#   829: '/title/tt0103855/',
#   830: '/title/tt0318627/',
#   831: '/title/tt1293847/',
#   832: '/title/tt1608290/',
#   833: '/title/tt0479884/',
#   834: '/title/tt0408306/',
#   835: '/title/tt1599348/',
#   836: '/title/tt1213663/',
#   837: '/title/tt3076658/',
#   838: '/title/tt0212346/',
#   839: '/title/tt0311429/',
#   840: '/title/tt1464540/',
#   841: '/title/tt0378109/',
#   842: '/title/tt0442933/',
#   843: '/title/tt1615065/',
#   844: '/title/tt0111301/',
#   845: '/title/tt1206543/',
#   846: '/title/tt1798684/',
#   847: '/title/tt1219827/',
#   848: '/title/tt1219827/',
#   849: '/title/tt1135084/',
#   850: '/title/tt6372694/',
#   851: '/title/tt0409182/',
#   852: '/title/tt0277296/',
#   853: '/title/tt7520568/',
#   854: '/title/tt11057302/',
#   855: '/title/tt2294449/',
#   856: '/title/tt0137494/',
#   857: '/title/tt0426592/',
#   858: '/title/tt6205872/',
#   859: '/title/tt0430105/',
#   860: '/title/tt1617661/',
#   861: '/title/tt1194173/',
#   862: '/title/tt0119190/',
#   863: '/title/tt10763820/',
#   864: '/title/tt0087078/',
#   865: '/title/tt0389722/',
#   866: '/title/tt1823672/',
#   867: '/title/tt14199590/',
#   868: '/title/tt2172934/',
#   869: '/title/tt0424774/',
#   870: '/title/tt0119395/',
#   871: '/title/tt0086006/',
#   872: '/title/tt0146316/',
#   873: '/title/tt0107206/',
#   874: '/title/tt2788710/',
#   875: '/title/tt6533240/',
#   876: '/title/tt0215750/',
#   877: '/title/tt0103596/',
#   878: '/title/tt0090555/',
#   879: '/title/tt0859163/',
#   880: '/title/tt1911644/',
#   881: '/title/tt1911644/',
#   882: '/title/tt1397514/',
#   883: '/title/tt1272878/',
#   884: '/title/tt1618442/',
#   885: '/title/tt0362270/',
#   886: '/title/tt0084726/',
#   887: '/title/tt1185834/',
#   888: '/title/tt1321870/',
#   889: '/title/tt4849438/',
#   890: '/title/tt2592614/',
#   891: '/title/tt0120657/',
#   892: '/title/tt0365686/',
#   893: '/title/tt0811080/',
#   894: '/title/tt4769836/',
#   895: '/title/tt8093700/',
#   896: '/title/tt0268695/',
#   897: '/title/tt0365907/',
#   898: '/title/tt6521876/',
#   899: '/title/tt0373051/',
#   900: '/title/tt0963966/',
#   901: '/title/tt0293564/',
#   902: '/title/tt0440963/',
#   903: '/title/tt0095956/',
#   904: '/title/tt1172570/',
#   905: '/title/tt20726444/',
#   906: '/title/tt2548396/',
#   907: '/title/tt14168394/',
#   908: '/title/tt0107144/',
#   909: '/title/tt0092644/',
#   910: '/title/tt0119925/',
#   911: '/title/tt0119925/',
#   912: '/title/tt0406375/',
#   913: '/title/tt0106582/',
#   914: '/title/tt0114614/',
#   915: '/title/tt0091278/',
#   916: '/title/tt0758774/',
#   917: '/title/tt8179024/',
#   918: '/title/tt0089530/',
#   919: '/title/tt1843303/',
#   920: '/title/tt0372588/',
#   921: '/title/tt0084827/',
#   922: '/title/tt1860357/',
#   923: '/title/tt7547410/',
#   924: '/title/tt0257076/',
#   925: '/title/tt1648190/',
#   926: '/title/tt11116912/',
#   927: '/title/tt3758172/',
#   928: '/title/tt16360006/',
#   929: '/title/tt8883486/',
#   930: '/title/tt1098327/',
#   931: '/title/tt0790736/',
#   932: '/title/tt0107076/',
#   933: '/title/tt0462322/',
#   934: '/title/tt1188729/',
#   935: '/title/tt1059786/',
#   936: '/title/tt5012504/',
#   937: '/title/tt0087597/',
#   938: '/title/tt0062395/',
#   939: '/title/tt0062395/',
#   940: '/title/tt1038686/',
#   941: '/title/tt5177088/',
#   942: '/title/tt0120177/',
#   943: '/title/tt5617712/',
#   944: '/title/tt0064615/',
#   945: '/title/tt2404463/',
#   946: '/title/tt0425061/',
#   947: '/title/tt2446042/',
#   948: '/title/tt5717194/',
#   949: '/title/tt0944835/',
#   950: '/title/tt0421073/',
#   951: '/title/tt0457400/',
#   952: '/title/tt1408253/',
#   953: '/title/tt7693316/',
#   954: '/title/tt0252503/',
#   955: '/title/tt0450405/',
#   956: '/title/tt0091499/',
#   957: '/title/tt9691136/',
#   958: '/title/tt2638144/',
#   959: '/title/tt0829150/',
#   960: '/title/tt1615160/',
#   961: '/title/tt11301946/',
#   962: '/title/tt0435705/',
#   963: '/title/tt0477080/',
#   964: '/title/tt0477080/',
#   965: '/title/tt11873440/',
#   966: '/title/tt0314353/',
#   967: '/title/tt0983193/',
#   968: '/title/tt0086859/',
#   969: '/title/tt6148156/',
#   970: '/title/tt1446192/',
#   971: '/title/tt0103893/',
#   972: '/title/tt0116253/',
#   973: '/title/tt0067116/',
#   974: '/title/tt4560436/',
#   975: '/title/tt8134742/',
#   976: '/title/tt9389998/',
#   977: '/title/tt14948432/',
#   978: '/title/tt18563148/',
#   979: '/title/tt0295701/',
#   980: '/title/tt0327850/',
#   981: '/title/tt1961175/',
#   982: '/title/tt0067525/',
#   983: '/title/tt3876910/',
#   984: '/title/tt1211956/',
#   985: '/title/tt0081573/',
#   986: '/title/tt0364970/',
#   987: '/title/tt0068638/',
#   988: '/title/tt1512235/',
#   989: '/title/tt15255288/',
#   990: '/title/tt0119173/',
#   991: '/title/tt1686821/',
#   992: '/title/tt0177971/',
#   993: '/title/tt0266987/',
#   994: '/title/tt1071875/',
#   995: '/title/tt2937898/',
#   996: '/title/tt0096933/',
#   997: '/title/tt1764651/',
#   998: '/title/tt0338459/',
#   999: '/title/tt5057140/',
#   ...},
#  'movie title': {0: 'Top Gun: Maverick',
#   1: 'Jurassic World Dominion',
#   2: 'Top Gun',
#   3: 'Lightyear',
#   4: 'Spiderhead',
#   5: 'Everything Everywhere All at Once',
#   6: 'Interceptor',
#   7: 'Interceptor',
#   8: 'Black Adam',
#   9: 'The Northman',
#   10: 'Thor: Love and Thunder',
#   11: 'Fantastic Beasts: The Secrets of Dumbledore',
#   12: 'The Unbearable Weight of Massive Talent',
#   13: 'Jurassic Park',
#   14: 'Doctor Strange in the Multiverse of Madness',
#   15: 'No Time to Die',
#   16: 'The Batman',
#   17: 'Bullet Train',
#   18: 'Bullet Train',
#   19: 'Jurassic World',
#   20: 'Jurassic World: Fallen Kingdom',
#   21: 'Vikram',
#   22: 'Morbius',
#   23: 'The Lost City',
#   24: 'Spider-Man: No Way Home',
#   25: 'Last Seen Alive',
#   26: 'Sonic the Hedgehog 2',
#   27: 'Uncharted',
#   28: 'Prey',
#   29: 'Prey',
#   30: 'Prey',
#   31: 'Ambulance',
#   32: 'Ambulance',
#   33: 'The Lost World: Jurassic Park',
#   34: 'Dune',
#   35: 'Dune',
#   36: 'Jurassic Park III',
#   37: 'Star Wars',
#   38: 'The Gray Man',
#   39: 'Avengers: Endgame',
#   40: 'The Lady of Heaven',
#   41: 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   42: 'Eternals',
#   43: 'Free Guy',
#   44: 'The Matrix Resurrections',
#   45: 'Mission: Impossible',
#   46: 'Memory',
#   47: 'Memory',
#   48: 'Star Wars: Episode I - The Phantom Menace',
#   49: 'The Adam Project',
#   50: "The King's Man",
#   51: 'The Dark Knight',
#   52: 'Aquaman',
#   53: 'The Gentlemen',
#   54: 'Mission: Impossible - Fallout',
#   55: 'Samrat Prithviraj',
#   56: 'Blade Runner 2049',
#   57: 'Inception',
#   58: 'Moonfall',
#   59: 'Avatar: The Way of Water',
#   60: 'Major',
#   61: 'Star Wars: Episode III - Revenge of the Sith',
#   62: 'Mission: Impossible - Dead Reckoning - Part One',
#   63: 'The Contractor',
#   64: 'The Contractor',
#   65: 'Road House',
#   66: 'Mission: Impossible - Ghost Protocol',
#   67: 'Star Wars: Episode IX - The Rise of Skywalker',
#   68: 'Venom: Let There Be Carnage',
#   69: 'Heat',
#   70: 'Nobody',
#   71: 'Avatar',
#   72: 'The Suicide Squad',
#   73: 'Avengers: Infinity War',
#   74: 'Thor: Ragnarok',
#   75: 'Spree',
#   76: 'Guardians of the Galaxy',
#   77: 'The Last Duel',
#   78: 'Mission: Impossible II',
#   79: 'Wrath of Man',
#   80: 'Pirates of the Caribbean: Dead Men Tell No Tales',
#   81: 'Star Wars: Episode II - Attack of the Clones',
#   82: 'Sonic the Hedgehog',
#   83: 'The Lord of the Rings: The Fellowship of the Ring',
#   84: 'Aquaman and the Lost Kingdom',
#   85: 'Star Wars: Episode VI - Return of the Jedi',
#   86: 'The Amazing Spider-Man',
#   87: 'Spectre',
#   88: 'The Hunger Games: The Ballad of Songbirds and Snakes',
#   89: 'Watchmen',
#   90: 'Tenet',
#   91: 'Shang-Chi and the Legend of the Ten Rings',
#   92: 'Ghostbusters',
#   93: 'The Hunger Games',
#   94: 'The Mortal Instruments: City of Bones',
#   95: 'Black Widow',
#   96: 'Willow',
#   97: 'Independence Day',
#   98: 'Mission: Impossible - Rogue Nation',
#   99: 'Casino Royale',
#   100: 'The Fifth Element',
#   101: 'Deadpool',
#   102: 'Doctor Strange',
#   103: 'Enola Holmes',
#   104: 'Divergent',
#   105: 'The Accountant',
#   106: 'Spider-Man',
#   107: 'Operation Fortune: Ruse de guerre',
#   108: "Zack Snyder's Justice League",
#   109: 'Die Hard',
#   110: 'Mission: Impossible III',
#   111: 'Blade Runner',
#   112: 'Mad Max: Fury Road',
#   113: 'K.G.F: Chapter 2',
#   114: 'White Elephant',
#   115: 'Blacklight',
#   116: "Pirates of the Caribbean: Dead Man's Chest",
#   117: 'Spider-Man: Homecoming',
#   118: 'Resident Evil: Welcome to Raccoon City',
#   119: 'Captain Marvel',
#   120: 'Aliens',
#   121: '1917',
#   122: 'Star Wars: Episode VII - The Force Awakens',
#   123: 'The Matrix',
#   124: 'The Flash',
#   125: 'Gladiator',
#   126: 'Kingsman: The Secret Service',
#   127: 'Predator',
#   128: 'Red Notice',
#   129: 'Spider-Man: Into the Spider-Verse',
#   130: 'The Mummy',
#   131: 'Batman Begins',
#   132: 'Star Wars: Episode VIII - The Last Jedi',
#   133: '21 Bridges',
#   134: 'Apocalypto',
#   135: 'Jack Reacher',
#   136: 'Drive',
#   137: 'Pirates of the Caribbean: On Stranger Tides',
#   138: 'Oblivion',
#   139: 'The Hunt',
#   140: 'The Hunt',
#   141: '300',
#   142: 'Suicide Squad',
#   143: 'The Dark Knight Rises',
#   144: 'Starship Troopers',
#   145: 'The Old Guard',
#   146: 'The Lord of the Rings: The Return of the King',
#   147: "Pirates of the Caribbean: At World's End",
#   148: 'Black Panther',
#   149: 'Edge of Tomorrow',
#   150: 'Dunkirk',
#   151: 'The Marvels',
#   152: 'Baywatch',
#   153: 'Waterworld',
#   154: 'John Wick',
#   155: 'Twister',
#   156: 'Black Hawk Down',
#   157: 'Deadpool 2',
#   158: 'Thor',
#   159: 'Skyfall',
#   160: 'Iron Man',
#   161: 'Oldboy',
#   162: 'Oldboy',
#   163: 'The Man from Toronto',
#   164: 'Black Panther: Wakanda Forever',
#   165: 'The Informer',
#   166: 'Sicario',
#   167: 'Solo: A Star Wars Story',
#   168: 'Batman Forever',
#   169: 'Jumanji: The Next Level',
#   170: 'The Avengers',
#   171: 'The Terminator',
#   172: 'John Wick: Chapter 4',
#   173: 'Strange World',
#   174: 'Fury',
#   175: 'Ford v Ferrari',
#   176: 'Spider-Man 3',
#   177: 'The Tomorrow War',
#   178: 'Public Enemies',
#   179: 'Venom',
#   180: 'Brahmastra Part One: Shiva',
#   181: 'War of the Worlds',
#   182: 'War of the Worlds',
#   183: 'Fantastic Four',
#   184: 'Captain America: The First Avenger',
#   185: 'Terminator 2: Judgment Day',
#   186: 'Tropic Thunder',
#   187: 'Star Trek',
#   188: 'The Revenant',
#   189: 'Godzilla vs. Kong',
#   190: 'Guardians of the Galaxy Vol. 3',
#   191: 'Dune: Part Two',
#   192: 'Collateral',
#   193: 'The 355',
#   194: 'Baby Driver',
#   195: 'Only the Brave',
#   196: '10,000 BC',
#   197: '6 Underground',
#   198: 'Paws of Fury: The Legend of Hank',
#   199: 'The Amazing Spider-Man 2',
#   200: 'Jungle Cruise',
#   201: 'Infinite',
#   202: 'The Fast and the Furious',
#   203: 'Guardians of the Galaxy Vol. 2',
#   204: 'Fast X',
#   205: 'Justice League',
#   206: 'Batman',
#   207: 'Batman',
#   208: 'DC League of Super-Pets',
#   209: 'Spider-Man: Across the Spider-Verse',
#   210: 'Speed',
#   211: 'Indiana Jones and the Last Crusade',
#   212: 'The Last Samurai',
#   213: 'The Last Samurai',
#   214: 'Transformers',
#   215: 'Logan',
#   216: 'Armageddon',
#   217: 'Spider-Man: Far from Home',
#   218: 'Ready or Not',
#   219: 'The Crow',
#   220: 'Kill Bill: Vol. 1',
#   221: 'Minority Report',
#   222: 'Ready Player One',
#   223: 'Hell or High Water',
#   224: 'Man of Steel',
#   225: 'The Lord of the Rings: The Two Towers',
#   226: 'The Harder They Fall',
#   227: 'Kick-Ass',
#   228: 'Shazam!',
#   229: 'Jumanji: Welcome to the Jungle',
#   230: 'The Incredibles',
#   231: 'Con Air',
#   232: 'Wonder Woman 1984',
#   233: 'Predestination',
#   234: 'Indiana Jones and the Temple of Doom',
#   235: 'Avengers: Age of Ultron',
#   236: 'The School for Good and Evil',
#   237: 'The Fighter',
#   238: 'Kingsman: The Golden Circle',
#   239: 'Wonder Woman',
#   240: 'Knowing',
#   241: 'Mortal Kombat',
#   242: 'Zombieland',
#   243: 'El Camino: A Breaking Bad Movie',
#   244: 'The Magnificent Seven',
#   245: 'The Other Guys',
#   246: 'Transformers: Rise of the Beasts',
#   247: 'Hellboy',
#   248: 'The Maze Runner',
#   249: 'Raya and the Last Dragon',
#   250: 'Men in Black',
#   251: 'Shazam! Fury of the Gods',
#   252: 'Midnight in the Switchgrass',
#   253: 'Army of the Dead',
#   254: "Hitman's Wife's Bodyguard",
#   255: 'Scott Pilgrim vs. the World',
#   256: 'Captain America: Civil War',
#   257: "The Hitman's Bodyguard",
#   258: 'The Predator',
#   259: 'Quantum of Solace',
#   260: 'Days of Thunder',
#   261: 'Knight and Day',
#   262: 'Taken',
#   263: 'The Mask',
#   264: 'The Fugitive',
#   265: 'Thor: The Dark World',
#   266: 'Gods of Egypt',
#   267: 'Batgirl',
#   268: 'Rush',
#   269: 'Extraction',
#   270: 'The Rock',
#   271: 'World War Z',
#   272: 'Battleship',
#   273: 'K.G.F: Chapter 1',
#   274: 'Attack',
#   275: 'Batman & Robin',
#   276: 'The Tourist',
#   277: 'Alita: Battle Angel',
#   278: 'Batman Returns',
#   279: 'In Time',
#   280: 'The Equalizer',
#   281: 'Argylle',
#   282: 'V for Vendetta',
#   283: 'The Siege of Robin Hood',
#   284: 'The Bourne Identity',
#   285: 'Point Break',
#   286: 'Power Rangers',
#   287: 'Sucker Punch',
#   288: 'X-Men',
#   289: "Don't Breathe 2",
#   290: 'Army of Thieves',
#   291: 'Superman',
#   292: 'The Incredible Hulk',
#   293: 'Highlander',
#   294: 'Kaithi',
#   295: 'Kingdom of Heaven',
#   296: 'Greenland',
#   297: 'The Legend of Tarzan',
#   298: 'The Meg',
#   299: 'Game Night',
#   300: 'X-Men: Apocalypse',
#   301: 'King Arthur: Legend of the Sword',
#   302: 'Den of Thieves',
#   303: 'Face/Off',
#   304: 'Murder Mystery',
#   305: 'Snake Eyes',
#   306: 'From Dusk Till Dawn',
#   307: 'The Hunger Games: Catching Fire',
#   308: "Ocean's Eight",
#   309: 'RED',
#   310: 'The Karate Kid',
#   311: 'GoldenEye',
#   312: 'How to Train Your Dragon',
#   313: 'Total Recall',
#   314: 'Pineapple Express',
#   315: 'Warrior',
#   316: 'Wolf Hound',
#   317: 'Jack Reacher: Never Go Back',
#   318: 'Harry Potter and the Order of the Phoenix',
#   319: 'Hot Fuzz',
#   320: 'Allied',
#   321: 'American Made',
#   322: 'First Blood',
#   323: 'The New Mutants',
#   324: 'Eraser',
#   325: 'Unlocked',
#   326: 'The Spy Who Never Dies',
#   327: 'Training Day',
#   328: 'Love and Monsters',
#   329: 'The Patriot',
#   330: 'Rango',
#   331: 'Chaos Walking',
#   332: 'Wanted',
#   333: 'Rush Hour',
#   334: 'Endangered Species',
#   335: 'Spider-Man 2',
#   336: 'Transformers: The Last Knight',
#   337: 'Midnight Run',
#   338: 'Ip Man: The Awakening',
#   339: 'Overlord',
#   340: 'Dr. No',
#   341: 'Ava',
#   342: 'Conan the Barbarian',
#   343: 'Tomb Raider',
#   344: 'Old Henry',
#   345: 'Harry Potter and the Half-Blood Prince',
#   346: "Logan's Run",
#   347: 'Captain America: The Winter Soldier',
#   348: 'Hard to Kill',
#   349: 'Open Range',
#   350: 'The Rocketeer',
#   351: 'The Nice Guys',
#   352: 'Pearl Harbor',
#   353: 'Snowpiercer',
#   354: 'Kung Fu Panda',
#   355: 'Looper',
#   356: 'John Wick: Chapter 3 - Parabellum',
#   357: 'Batman v Superman: Dawn of Justice',
#   358: 'Inferno',
#   359: 'Inferno',
#   360: 'Planet of the Apes',
#   361: 'King Kong',
#   362: 'Masters of the Universe',
#   363: 'Smokey and the Bandit',
#   364: 'Miami Vice',
#   365: 'Polar',
#   366: 'Lock, Stock and Two Smoking Barrels',
#   367: 'Jumper',
#   368: 'Mulan',
#   369: 'Blade',
#   370: '2012',
#   371: 'Gold',
#   372: 'Gold',
#   373: 'The Day After Tomorrow',
#   374: 'The Warriors',
#   375: 'The Warriors',
#   376: '13 Hours',
#   377: 'The Protégé',
#   378: 'Teenage Mutant Ninja Turtles',
#   379: 'Teenage Mutant Ninja Turtles',
#   380: 'Mr. & Mrs. Smith',
#   381: 'Iron Man 2',
#   382: 'Constantine',
#   383: 'Pacific Rim',
#   384: 'Incredibles 2',
#   385: 'Ant-Man',
#   386: 'G.I. Joe: The Rise of Cobra',
#   387: 'Big Hero 6',
#   388: 'Man on Fire',
#   389: 'Terminator: Dark Fate',
#   390: 'X-Men: Days of Future Past',
#   391: 'Tag',
#   392: 'Tag',
#   393: 'Robin Hood',
#   394: 'Central Intelligence',
#   395: 'Death Proof',
#   396: 'Shooter',
#   397: 'Never Back Down',
#   398: 'Angel Has Fallen',
#   399: 'The Princess',
#   400: 'Live Free or Die Hard',
#   401: 'Dredd',
#   402: "Charlie's Angels",
#   403: 'Hitman: Agent 47',
#   404: 'The Fast and the Furious: Tokyo Drift',
#   405: 'Hitman',
#   406: 'Hitman',
#   407: 'Triple Frontier',
#   408: '21 Jump Street',
#   409: 'Warcraft',
#   410: 'Falling Down',
#   411: 'District 9',
#   412: 'RoboCop',
#   413: 'The Mummy Returns',
#   414: 'Beverly Hills Cop',
#   415: 'Pokémon: Detective Pikachu',
#   416: 'Star Trek Beyond',
#   417: 'Copshop',
#   418: 'Children of Men',
#   419: 'The Man from U.N.C.L.E.',
#   420: 'American Sniper',
#   421: 'Eraser: Reborn',
#   422: 'Rambo: Last Blood',
#   423: 'Resident Evil',
#   424: 'Mandy',
#   425: 'Tomorrow Never Dies',
#   426: 'Midway',
#   427: 'Red Sparrow',
#   428: 'Revenge',
#   429: 'We Can Be Heroes',
#   430: 'Samaritan',
#   431: 'Underwater',
#   432: 'Fast & Furious',
#   433: '3:10 to Yuma',
#   434: 'Mad Max',
#   435: 'Over the Top',
#   436: 'The Losers',
#   437: 'Hot Shots!',
#   438: 'A History of Violence',
#   439: 'Gunpowder Milkshake',
#   440: 'The Fate of the Furious',
#   441: 'Logan Lucky',
#   442: 'Red Dawn',
#   443: 'Red Dawn',
#   444: 'Vendetta',
#   445: 'Vendetta',
#   446: 'Hulk',
#   447: 'Ant-Man and the Wasp: Quantumania',
#   448: 'Stargate',
#   449: 'The Last of the Mohicans',
#   450: 'Dick Tracy',
#   451: 'U.S. Marshals',
#   452: 'Godzilla: King of the Monsters',
#   453: 'In the Heart of the Sea',
#   454: 'Allegiant',
#   455: 'Deep Impact',
#   456: 'Angels & Demons',
#   457: 'The Blues Brothers',
#   458: 'The Last Airbender',
#   459: 'The Quick and the Dead',
#   460: 'Sherlock Holmes',
#   461: 'The Book of Eli',
#   462: 'Sicario: Day of the Soldado',
#   463: 'Kong: Skull Island',
#   464: 'Forsaken',
#   465: 'Forsaken',
#   466: 'Fast Five',
#   467: 'Snow White and the Huntsman',
#   468: 'Star Trek Into Darkness',
#   469: 'Bumblebee',
#   470: 'Enola Holmes 2',
#   471: 'The Roundup',
#   472: 'Rocketry: The Nambi Effect',
#   473: 'Law Abiding Citizen',
#   474: 'Kate',
#   475: 'Deep Blue Sea',
#   476: 'John Wick: Chapter 2',
#   477: 'They Live',
#   478: 'The Saint',
#   479: 'Predators',
#   480: 'The Guest',
#   481: 'The Vault',
#   482: 'The Vault',
#   483: 'Deadpool 3',
#   484: 'Pixels',
#   485: 'Van Helsing',
#   486: 'The Silencing',
#   487: 'Small Soldiers',
#   488: 'Die Hard 2',
#   489: 'The Last Castle',
#   490: 'National Treasure',
#   491: 'Geostorm',
#   492: 'Fast & Furious Presents: Hobbs & Shaw',
#   493: 'Independence Day: Resurgence',
#   494: 'Ant-Man and the Wasp',
#   495: 'Napoleon',
#   496: 'Napoleon',
#   497: 'Green Lantern',
#   498: 'Big Trouble in Little China',
#   499: 'Hotel Mumbai',
#   500: 'X-Men Origins: Wolverine',
#   501: 'Anek',
#   502: 'Double Threat',
#   503: 'Pain & Gain',
#   504: 'I Am Legend',
#   505: 'Greyhound',
#   506: 'Lucy',
#   507: 'The Forever Purge',
#   508: 'Super 8',
#   509: "Willy's Wonderland",
#   510: 'The Twilight Saga: Eclipse',
#   511: 'Hunter Killer',
#   512: 'Olympus Has Fallen',
#   513: 'Bad Boys for Life',
#   514: 'Romancing the Stone',
#   515: 'Tomorrowland',
#   516: 'No Way Out',
#   517: 'No Way Out',
#   518: 'Sky High',
#   519: 'Sky High',
#   520: 'Ghost Rider',
#   521: 'Bad Boys',
#   522: 'Deja Vu',
#   523: 'Cloverfield',
#   524: 'Men in Black 3',
#   525: 'Daybreakers',
#   526: 'Corrective Measures',
#   527: 'Underworld',
#   528: 'The Colony',
#   529: 'The Colony',
#   530: 'Drive Angry',
#   531: 'Ghostbusters II',
#   532: 'The Outpost',
#   533: 'Natural Born Killers',
#   534: 'Hollow Man',
#   535: "Dante's Peak",
#   536: 'John Carter',
#   537: 'The Matrix Reloaded',
#   538: 'A View to a Kill',
#   539: 'The Hunt for Red October',
#   540: 'Spiral',
#   541: 'Spiral',
#   542: 'Spiral',
#   543: 'Spiral',
#   544: 'Alien³',
#   545: 'Extraction 2',
#   546: 'Transcendence',
#   547: 'Goldfinger',
#   548: 'The Transporter',
#   549: 'Rambo: First Blood Part II',
#   550: 'The Shallows',
#   551: 'Robin Hood: Prince of Thieves',
#   552: 'Adrift',
#   553: '2 Fast 2 Furious',
#   554: 'Escape from New York',
#   555: 'Anna',
#   556: 'Clean',
#   557: 'Indiana Jones and the Kingdom of the Crystal Skull',
#   558: 'Bullitt',
#   559: 'The Finest Hours',
#   560: 'Day Shift',
#   561: 'Predator 2',
#   562: 'I Saw the Devil',
#   563: 'I Saw the Devil',
#   564: 'Spy Kids',
#   565: 'Godzilla',
#   566: 'The Lego Movie',
#   567: 'Kill Bill: Vol. 2',
#   568: 'The Longest Day',
#   569: 'The World Is Not Enough',
#   570: 'The Count of Monte Cristo',
#   571: 'Atomic Blonde',
#   572: 'Lone Survivor',
#   573: 'A Day to Die',
#   574: 'Atlantis: The Lost Empire',
#   575: 'Serenity',
#   576: 'Dawn of the Dead',
#   577: 'Freddy vs. Jason',
#   578: 'Dirty Harry',
#   579: 'Terminator Genisys',
#   580: 'Commando',
#   581: 'Gone in 60 Seconds',
#   582: 'Gone in 60 Seconds',
#   583: 'Last Action Hero',
#   584: 'Borderlands',
#   585: 'The Boondock Saints',
#   586: 'Kick-Ass 2',
#   587: 'Scouts Guide to the Zombie Apocalypse',
#   588: 'Upgrade',
#   589: 'North by Northwest',
#   590: '300: Rise of an Empire',
#   591: 'Superman III',
#   592: 'X-Men: The Last Stand',
#   593: 'Anaconda',
#   594: 'Mortal Engines',
#   595: 'Kraven the Hunter',
#   596: 'Young Guns',
#   597: '13 Minutes',
#   598: '13 Minutes',
#   599: 'Dungeons & Dragons',
#   600: 'Dungeons & Dragons',
#   601: 'Live and Let Die',
#   602: 'Valerian and the City of a Thousand Planets',
#   603: 'Kindergarten Cop',
#   604: 'Unhinged',
#   605: 'Unbroken',
#   606: 'Gravity',
#   607: 'From Russia with Love',
#   608: 'The Hunger Games: Mockingjay - Part 2',
#   609: 'Reign of Fire',
#   610: 'True Lies',
#   611: 'Escape Room',
#   612: 'The Running Man',
#   613: "A Knight's Tale",
#   614: 'Those Who Wish Me Dead',
#   615: 'SAS: Red Notice',
#   616: 'Pacific Rim: Uprising',
#   617: 'Barb Wire',
#   618: 'Escape Room: Tournament of Champions',
#   619: 'Peter Pan & Wendy',
#   620: 'Carriers',
#   621: 'Desperado',
#   622: 'The Guardian',
#   623: 'The Guardian',
#   624: 'Air Force One',
#   625: 'Speed 2: Cruise Control',
#   626: 'Push',
#   627: 'A Good Day to Die Hard',
#   628: 'Howard the Duck',
#   629: 'Licence to Kill',
#   630: 'Pompeii',
#   631: 'The Spy Who Loved Me',
#   632: 'Now You See Me 2',
#   633: 'The Punisher',
#   634: 'The Cannonball Run',
#   635: 'Riddick',
#   636: 'Eragon',
#   637: 'Monster Hunter',
#   638: 'Die Another Day',
#   639: 'Teenage Mutant Ninja Turtles: Out of the Shadows',
#   640: 'Thunderball',
#   641: 'Transformers: Age of Extinction',
#   642: 'Layer Cake',
#   643: 'Kung Fu Panda 3',
#   644: 'Clash of the Titans',
#   645: 'Panama',
#   646: 'Alphas',
#   647: 'Sweet Girl',
#   648: 'Men in Black: International',
#   649: 'Firestarter',
#   650: 'The Man with the Golden Gun',
#   651: 'There Are No Saints',
#   652: 'The Iron Giant',
#   653: 'G.I. Joe: Retaliation',
#   654: 'Men in Black II',
#   655: 'The Wild Bunch',
#   656: 'Blade: Trinity',
#   657: 'San Andreas',
#   658: 'Maverick',
#   659: 'Zombieland: Double Tap',
#   660: 'Ip Man',
#   661: 'The Island',
#   662: 'Bloodsport',
#   663: "On Her Majesty's Secret Service",
#   664: 'How to Train Your Dragon: The Hidden World',
#   665: 'For Your Eyes Only',
#   666: 'The Lone Ranger',
#   667: 'Rise of the Planet of the Apes',
#   668: 'Lethal Weapon',
#   669: 'Hercules',
#   670: 'Hercules',
#   671: 'Austin Powers in Goldmember',
#   672: 'The Chronicles of Riddick',
#   673: 'Sin City: A Dame to Kill For',
#   674: 'We Were Soldiers',
#   675: 'Alexander',
#   676: 'Austin Powers: The Spy Who Shagged Me',
#   677: 'Congo',
#   678: 'Everest',
#   679: 'The 5th Wave',
#   680: 'The Lego Batman Movie',
#   681: 'Rogue',
#   682: 'War for the Planet of the Apes',
#   683: 'RocknRolla',
#   684: 'Jason Bourne',
#   685: 'White House Down',
#   686: 'Terminator Salvation',
#   687: 'Mortdecai',
#   688: 'Megamind',
#   689: 'Homefront',
#   690: 'Maze Runner: The Death Cure',
#   691: 'The Equalizer 2',
#   692: '12 Strong',
#   693: 'Elysium',
#   694: 'Havoc',
#   695: 'The Expendables 3',
#   696: 'Dawn of the Planet of the Apes',
#   697: 'Kung Fu Panda 2',
#   698: '47 Ronin',
#   699: 'Ghosted',
#   700: 'Wicked',
#   701: 'Wicked',
#   702: 'Once Upon a Time in Mexico',
#   703: "Smokin' Aces",
#   704: 'Hansel & Gretel: Witch Hunters',
#   705: 'The Hunger Games: Mockingjay - Part 1',
#   706: 'Rambo',
#   707: 'Demolition Man',
#   708: 'Flash Gordon',
#   709: '48 Hrs.',
#   710: 'The Living Daylights',
#   711: 'Master and Commander: The Far Side of the World',
#   712: 'Source Code',
#   713: 'Nikamma',
#   714: 'Lifeforce',
#   715: 'The Negotiator',
#   716: 'Spy',
#   717: 'Sherlock Holmes 3',
#   718: 'Transformers: Revenge of the Fallen',
#   719: 'Master',
#   720: 'Master',
#   721: 'The Bourne Supremacy',
#   722: 'Diamonds Are Forever',
#   723: 'Outlaw King',
#   724: '28 Weeks Later',
#   725: 'Immortals',
#   726: "The King's Daughter",
#   727: 'Superman Returns',
#   728: 'Daredevil',
#   729: 'Transformers: Dark of the Moon',
#   730: 'Rampage',
#   731: 'Thunder Force',
#   732: 'King Arthur',
#   733: 'The Italian Job',
#   734: 'The Wolverine',
#   735: 'Fallen',
#   736: 'Blue Beetle',
#   737: 'Noah',
#   738: "The Huntsman: Winter's War",
#   739: 'The Ridiculous 6',
#   740: 'The Dirty Dozen',
#   741: 'Westworld',
#   742: 'Cloak & Dagger',
#   743: 'My Spy',
#   744: 'Enemy of the State',
#   745: 'Bad Boys II',
#   746: 'Without Remorse',
#   747: 'WarGames',
#   748: 'Thar',
#   749: 'The Expendables',
#   750: 'Exodus: Gods and Kings',
#   751: 'The Bad Batch',
#   752: 'Pride and Prejudice and Zombies',
#   753: 'How to Train Your Dragon 2',
#   754: "Fool's Gold",
#   755: 'Bright',
#   756: 'Octopussy',
#   757: 'Terminator 3: Rise of the Machines',
#   758: 'Bloodshot',
#   759: 'Non-Stop',
#   760: 'Species',
#   761: 'The Mask of Zorro',
# ...
#   960: "83quantilevalu action thriller a humbl businessman with a buri past seek justic when hi daughter is kill in an act of terrorism. a cat-and-mous conflict ensu with a govern official, whose past may hold clue to the killers' identities. gun justic terror explos londonengland handgun death deathofdaught affair restaur martincampbel stephenleath katieleung jackiechan rufusjon martincampbel davidmarconi 2017 6.6667 7.0000",
#   961: '72quantilevalu action comedi thriller after a shop mall in chennai is hijack by terrorist who hold the visitor as hostages, veera raghavan, a spi also trap in the mall, decid to save the hostag by elimin the terrorists. hostag diehardscenario blackcomedi aerialcombat actionhero nelsondilipkumar thalapathyvijay poojahegd k.selvaraghavan nelsondilipkumar nelsondilipkumar nelsondilipkumar 2022 5.0000 5.3333',
#   962: '85quantilevalu action sci-fi thriller a la vega magician who can see into the futur is pursu by fbi agent seek to use hi abil to prevent a nuclear terrorist attack. womaninjeopardi tapeovermouth 7elevenstor timetravel fowardstimetravel timeloop backwardstimetravel bulletdodg fbifederalbureauofinvestig blackjack leetamahori jonathanhensleigh paulbernbaum nicolascag juliannemoor jessicabiel garygoldman 2007 6.0000 6.3333',
#   963: '86quantilevalu action thriller with an unmanned, half-mile-long freight train barrel toward a city, a veteran engin and a young conductor race against the clock to prevent a catastrophe. train runawaytrain trainengin freighttrain trainmovi hooter basedontruestori disasterfilm afghanistanwarveteran africanamerican tonyscott denzelwashington chrispin rosariodawson tonyscott markbomback markbomback 2010 6.6667 7.0000',
#   964: '40quantilevalu action crime thriller dong-chul (don lee) and ji-soo (song ji-hyo) are a happili marri couple. one day, dong-chul come home to find hi hous in disarray and hi wife is missing. hous kimmin-ho madong-seok songji-hyo kimsung-oh kimmin-ho kimmin-ho kimmin-ho 2010 6.3333 6.6667',
#   965: "70quantilevalu action romanc babloo ranawat, a geniu hacker, is task with track down laila, the mastermind behind the world' largest cyber-crim yet to occur. will babloo be abl to stop him? spyaction mission ahmedkhan sajidnadiadwala tigershroff nawazuddinsiddiqui tarasutaria ahmedkhan rajatarora 2022 3.3333 3.6667",
#   966: '84quantilevalu action drama thriller a special-op command lead hi team into the nigerian jungl in order to rescu a doctor who will onli join them if they agre to save 70 refuge too. nigeria civilwar refuge rescuemiss africa machet murderofapriest astronomicalobjectintitl rebel border antoinefuqua patrickcirillo brucewilli colehaus monicabellucci antoinefuqua alexlask 2003 6.3333 6.6667',
#   967: "87quantilevalu anim action adventur intrepid report tintin and captain haddock set off on a treasur hunt for a sunken ship command by haddock' ancestor. treasur dog ship captain modelship report basedoncomicbook boat alcohol journalist stevenspielberg stevenmoffat edgarwright jamiebel andyserki danielcraig hergé 2011 7.0000 7.3333",
#   968: '61quantilevalu action adventur crime a gangster hire an ex-footbal player to find hi girlfriend. when he find her, they fall in love, and the twist start to appear. nightclub mexico gangster sexscen losangelescalifornia beach femmefatal lovetriangl murder obsessivelov taylorhackford danielmainwar rachelward jeffbridg jameswood taylorhackford erichugh 1984 5.6667 6.0000',
#   969: "74quantilevalu action crime drama vikram, a no-nonsens polic officer, accompani by simon, hi partner, is on the hunt to captur vedha, a smuggler and a murderer. vedha tri to chang vikram' life, which lead to a conflict. gangster fight gunfight shootout sledgehamm twowordtitl brother wife hand moraldilemma gayatri manikandank. gautamsiddharth gayatri madhavan vijaysethupathi pushkar 2017 8.0000 8.3333",
#   970: '86quantilevalu anim action adventur when the evil spirit pitch launch an assault on earth, the immort guardian team up to protect the innoc of children all around the world. santaclauscharact jackfrostcharact sandmancharact toothfairycharact easterbunnycharact boogeyman abominablesnowmancharact closeupofey brothersisterrelationship brothersaveshissist peterramsey williamjoyc hughjackman alecbaldwin islafish peterramsey davidlindsay-abair 2012 7.0000 7.3333',
#   971: "76quantilevalu action comedi fantasi flighti teenag girl buffi summer learn that she is her generation' destin battler of vampires. femaleprotagonist teenagegirl 1990 femalewarrior mentorstudentrelationship destini highschool comingofag satir femalevampir franrubelkuzui kristyswanson donaldsutherland paulreuben franrubelkuzui josswhedon josswhedon 1992 5.3333 5.6667",
#   972: '78quantilevalu action adventur thriller when terrorist seiz control of an airliner, an intellig analyst accompani a commando unit for a midair board operation. stealthplan bomb mission lockheedf117nighthawk f14tomcat muslim islam muslimman referencetoallah islam stuartbaird johnthoma kurtrussel halleberri johnleguizamo stuartbaird jimthoma 1996 6.3333 6.6667',
#   973: '84quantilevalu action crime drama a pair of nypd detect in the narcot bureau stumbl onto a heroin smuggl ring base in marseilles, but stop them and captur their leader prove an elus goal. basedontruestori triggerman criminalinvestig heroin smuggl druglord newyorkc drugsmuggl carchas bagman williamfriedkin robinmoor genehackman royscheid fernandorey williamfriedkin ernesttidyman 1971 7.6667 8.0000',
#   974: '81quantilevalu action thriller a small team of elit american intellig officers, part of a top-secret tactic command unit, tri to smuggl a mysteri polic offic with sensit inform out of indonesia. surveil cesium handgrenad martialart mixedmartialart handtohandcombat gunfight shootout streetshootout betray peterberg leacarpent markwahlberg laurencohan ikouwai peterberg grahamroland 2018 6.0000 6.3333',
#   975: '64quantilevalu action horror after bare surviv prison, the dement firefli clan go on the run, unleash a whole new wave of murder, mad and mayhem. femalenud barebreast serialkillerfamili familyofserialkil femalepsychopath evil misanthropi brutal tortur sadism robzombi sherimoonzombi billmoseley sidhaig robzombi robzombi robzombi 2019 5.3333 5.6667',
#   976: '79quantilevalu action adventur crime stori of pushpa raj, a lorri driver in seshachalam forest of south india, set in the backdrop of red sandalwood smuggling. red sandalwood is endem to south-eastern ghat (mountain range) of india. smuggl sukumar srikanthvissa hussainshakiran alluarjun fahadhfaasil rashmikamandanna sukumar 2021 7.3333 7.6667',
#   977: '0quantilevalu action adventur comedi plot under wraps. jakekasdan chrismorgan chrisevan dwaynejohnson jakekasdan hiramgarcia hiramgarcia 2023 5.6667 6.0000',
#   978: '41quantilevalu action crime drama follow three young freedom fighter who seek refug in a south african bank in silverton, and take the bank and it custom hostag and would onli releas them in exchang for the releas of nelson mandela. crimin hostag robber robberi bank money trio target mission gun mandladub thaborametsi arnoldvosloo noxolodlamini mandladub sabelomgidi sabelomgidi 2022 6.0000 6.3333',
#   979: '86quantilevalu action adventur thriller an extrem sport athlete, xander cage, is recruit by the govern on a special mission. snowboard timebomb kidnap tattooontorso adventurehero physicalskil psychologicalskil waterborndron targetinginform freezingriv robcohen vindiesel asiaargento martoncsoka robcohen richwilk richwilk 2002 5.6667 6.0000',
#   980: "83quantilevalu action adventur comedi a tough aspir chef is hire to bring home a mobster' son from the amazon but becom involv in the fight against an oppress town oper and the search for a legendari treasure. jungl bountyhunt brazil goldmin buddi toughguy surpriseend maleobjectif punchintothecamera stripmin peterberg jamesvanderbilt dwaynejohnson seannwilliamscott christopherwalken peterberg r.j.stewart 2003 6.3333 6.6667",
#   981: "81quantilevalu action thriller after the death of hi girlfriend at the hand of terrorists, mitch rapp is drawn into the world of counterterrorism, mentor by tough-as-nail former u.s. navi s.e.a.l. stan hurley. terror reveng beach fight train islamicterror spi assassin mentor lossoffiance michaelcuesta michaelfinch edwardzwick dylano'brien michaelkeaton sanaalathan stephenschiff 2017 6.0000 6.3333",
#   982: '72quantilevalu action drama sci-fi biolog war ha decim life on earth. lo angel is a windswept ghost town where robert nevil tool hi convert through sunlit street forag for supplies. plagu postapocalyps basedonnovel globalpandem antidot albino dystopia mutant surviv lastmanonearth borissag joycehoopercorrington richardmatheson charltonheston anthonyzerb rosalindcash johnwilliamcorrington 1971 6.3333 6.6667',
#   983: "50quantilevalu action thriller a reform sociopath journey to a remot island to investig the mysteri behind hi brother' demise, but soon end up face off with more than he bargain for. violenc rrate excon lithium breakingpoint parol shootout antidepress eccentricpsychiatrist exposingthetruth davidhackl scotteastwood kevindurand famkejanssen davidhackl christopherborrelli christopherborrelli 2021 5.0000 5.3333",
#   984: "87quantilevalu action thriller when a structural-secur author find himself set up and incarcer in the world' most secret and secur prison, he ha to use hi skill to escap with help from the inside. prison prison escap ship underwaterscen reveng fire friendship tortur prisonriot mikaelhåfström jasonkel sylvesterstallon arnoldschwarzenegg 50cent mikaelhåfström mileschapman 2013 6.6667 7.0000",
#   985: '83quantilevalu action adventur sci-fi superman agre to sacrific hi power to start a relationship with loi lane, unawar that three kryptonian crimin he inadvert releas are conquer earth. superhero secondpart sequel basedoncom dccomic femalekryptonian femalealien romannumberedsequel phantomzon femalesupervillain richardlest jerrysiegel joeshust mariopuzo genehackman christopherreev richarddonn 1980 6.6667 7.0000',
#   986: '82quantilevalu action adventur sci-fi veteran-turned-mercenari toorop take the high-risk job of escort a woman from russia to america. littl doe he know that she is host to an organ that a cult want to harvest in order to produc a genet modifi messiah. veteranturnedmercenari cult roadmovi armoredcar virginbirth flashback streetviol scientist nun geneticalter mathieukassovitz mathieukassovitz éricbesnard vindiesel michelleyeoh mélaniethierri mauriceg.dantec 2008 5.3333 5.6667',
#   987: '73quantilevalu action crime thriller a recently-releas ex-con and hi loyal wife go on the run after a heist goe awry. neonoir timebomb crimeboss frustrat husbandslapswif shootoutinahotel trainstationlock ambush dysfunctionalmarriag texa sampeckinpah jimthompson stevemcqueen alimacgraw benjohnson sampeckinpah walterhil 1972 7.0000 7.3333',
#   988: '81quantilevalu action comedi crime after hi wife fall under the influenc of a drug dealer, an everyday guy transform himself into crimson bolt, a superhero with the best intentions, but lack in heroic skills. tragicomedi blackcomedi femaleonmalerap superhero comicbook vigilant sidekick tragiclov tragichero tragedi jamesgunn rainnwilson elliotpag livtyl jamesgunn jamesgunn jamesgunn 2010 6.6667 7.0000',
#   989: '0quantilevalu action comedi crime plot unknown, sequel to murder mystery. sequel secondpart parent blond theft lie murder kill friend jeremygarelick adamsandl jenniferaniston markstrong jeremygarelick jamesvanderbilt jamesvanderbilt 5.6667 6.0000',
#   990: '81quantilevalu action drama war a femal senat succe in enrol a woman into combin reconnaiss team train where everyon expect her to fail. femin militari train strongfemalecharact soldier femaleprotagonist femalesoldi sexism kickedinthecrotch kickedinthetesticl ridleyscott davidtwohi demimoor viggomortensen annebancroft ridleyscott daniellealexandra 1997 5.6667 6.0000',
#   991: '78quantilevalu action comedi drama rose hathaway is a dhampir, half human-half vampire, a guardian of the moroi, peaceful, mortal vampir live discreetli within our world. her call is to protect the moroi from bloodthirsty, immort vampires, the strigoi. vampir dhampir academi guardian princess train royal blood teenag halfvampir markwat richellemead zoeydeutch lucyfri danilakozlovskiy markwat danielwat 2014 5.3333 5.6667',
#   992: '86quantilevalu action adventur drama an unusu intens storm pattern catch some commerci fishermen unawar and put them in mortal danger. fish fish sea death seastorm fisherman stormatsea fishingboat icemachin fishingvessel wolfgangpetersen williamd.wittliff georgeclooney markwahlberg johnc.reilli wolfgangpetersen sebastianjung 2000 6.3333 6.6667',
#   993: '85quantilevalu action crime thriller retir cia agent nathan muir recal hi train of tom bishop while work against agenc polit to free him from hi chines captors. espionag shanghaichina taskforc ciaagent spi rogueag friendlyextract mentorprotegerelationship ciacentralintelligenceag americanabroad tonyscott davidarata robertredford bradpitt catherinemccormack tonyscott michaelfrostbeckn 2001 6.6667 7.0000',
#   994: "84quantilevalu action fantasi thriller johnni blaze, tortur by the ghost rider' curse, get a chanc of redempt through protect the devil' son, whose father is pursu him. marvelcom comicbookmovi weapon motorvehicl ghostridercharact vehicl psychotronicfilm columbiatristar partofduolog childinjeopardi markneveldin scottm.gimpl sethhoffman davids.goy nicolascag ciaránhind briantaylor 2011 4.0000 4.3333",
#   995: "80quantilevalu action crime drama in new york citi 1981, an ambiti immigr fight to protect hi busi and famili dure the most danger year in the city' history. newyorkc americandream oil year1981 immigr violenc childwithgun ambitiousman truckhijack oiltruck j.c.chandor oscarisaac jessicachastain davidoyelowo j.c.chandor j.c.chandor j.c.chandor 2014 6.6667 7.0000",
#   996: "78quantilevalu action crime thriller two nyc cop arrest a yakuza member and must escort him when he' extradit to japan. yakuza newyorkc americaninjapan murderofapoliceoffic languagebarri counterfeit investig arrest policeprocedur japan ridleyscott warrenlewi michaeldougla andygarcia kentakakura ridleyscott craigbolotin 1989 6.3333 6.6667",
#   997: '88quantilevalu action adventur thriller mr. church reunit the expend for what should be an easi paycheck, but when one of their men is murder on the job, their quest for reveng put them deep in enemi territori and up against an unexpect threat. womanfightsaman antitankmissil womanhitsaman womanmurdersaman murderess burial stabbedintheheart mustachedman brunett distaff simonwest sylvesterstallon kenkaufman sylvesterstallon liamhemsworth randycoutur richardwenk 2012 6.3333 6.6667',
#   998: "79quantilevalu action adventur comedi carmen' caught in a virtual realiti game design by the kids' new nemesis, the toymaker. it' up to juni to save hi sister, and ultim the world. machetecortezcharact espionag referencetovirtualrealitygam superhero slimehous titledirectedbymal titledirectedbyman titlewrittenbymal heroin malehero robertrodriguez darylsabara alexapenavega antoniobandera robertrodriguez robertrodriguez robertrodriguez 2003 4.0000 4.3333",
#   999: '74quantilevalu action drama thriller after the death of three children suspect to be kill by wolves, writer russel core is hire by the mother of a miss six-year-old boy to track down and locat her son in the alaskan wilderness. alaska wolv mysterystori darksecret writer clothedmalenakedfemalescen breast femalefullfrontalnud femalefrontalnud miss jeremysaulni williamgiraldi jeffreywright alexanderskarsgård jamesbadgedal jeremysaulni maconblair 2018 5.3333 5.6667',
#   ...}}

# %%
pickle.dump(new_df.to_dict(),open('movies_dict.pkl','wb'))

# %%
pickle.dump(similarity,open('similarity.pkl','wb'))
